# %% [markdown]
# # **ML pipeline**
#
# - This notebook contains the pre-processing and the model training phase
# - Why grouping the 2 steps ?
#     - This phase contains all the 'fit' steps : we will fit the encoder and the model so that it can be used later on during inference
# - Choice of the model : why choosing XGBoost ?
#     - `Time` : we don't dispose of a lot of time to benchmark multiple algorithms so we need to make a choice
#     - `Performance` : XGBoost has proven to be the winning solution algorithm in numerous hackathons (kaggle,...)
#     - `Calibration` : easy to calibrate and allows the user to perform regularization and prevent overfitting
#     - `Scalability` : fast and consistent execution time even with large datasets
#     - `Explainability` : TreeSHAP algorithm is able to calculate very accurate SHAP values for tree-based models
#     - `Conveniency` : The tree-base nature of the model allows us to skip multiple pre-processing steps such as normalization, standardization & extreme values processing

# %%
import sys
from pathlib import Path
import logging 
import warnings
warnings.filterwarnings('ignore')

LOGGER = logging.getLogger(__name__)
sys.path.append(str(Path("../src").resolve())) 

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## **Parameters**

# %%
columns_to_remove = ["policy_bind_date", "incident_date", "total_claim_amount"]
features_type_mapping = {
    'policy_state': "str", 
    'insured_education_level': "str", 
    'insured_occupation': "str",
    'insured_hobbies': "str", 
    'incident_type': "str", 
    'collision_type': "str",
    'incident_severity': "str", 
    'authorities_contacted': "str", 
    'incident_state': "str",
    'incident_city': "str", 
    'property_damage': "str", 
    'police_report_available': "str",
    'auto_make': "str"
}
binary_columns_list = ["property_damage", "police_report_available"]
unknown_value = -1
test_size = 0.2
shuffle = True
random_state = 1234
hyperparameters = {
    "booster" : "gbtree", # NOTE: we wan't tree-based boosting
    "objective": "binary:logistic", # NOTE : it is a binary classification
    "n_estimators": 1000, 
    "eta": 0.01, # NOTE : rule of thumb n_estimator ~10/eta
    "min_child_weight": 1, # NOTE : if too little it can lead to overfitting
    "seed": 1234, # NOTE : it is a binary classification
    "n_jobs": 5, # NOTE : number of cores to use to speed up calculation time
    "base_score": 0.25, # NOTE : % of 1 in the labels -> helps the model to converge faster
    "max_depth": 10, # NOTE : if too high it can lead to overfitting, increase if the nb of features is high
    "subsample": 0.8, # NOTE : % of rows to sample each step -> regularization
    "colsample_bytree": 0.75, # NOTE : % of columns to sample each step -> regularization, to decrease if we have a lot of columns
    "eval_metric": ["auc", "logloss"], # NOTE : we will minimize the loss and observe the auc
}
training_params = {"early_stopping_rounds": 15}

# %% [markdown]
# ## **Input loading**

# %%
import polars as pl 
from pathlib import Path

instances = pl.read_parquet(source=(Path().cwd().parent / "data/02_intermediate/instances.parquet").as_posix()).to_pandas()
labels = pl.read_parquet(source=(Path().cwd().parent / "data/02_intermediate/labels.parquet").as_posix()).to_pandas()

# %% [markdown]
# ## **Execution**

# %%
import functions.ml.preprocessing_functions as preprocessing 
import functions.ml.ml_training_functions as ml_training
import functions.ml.model_explanation_functions as explanation 
import functions.ml.model_prediction_functions as prediction 
import functions.ml.model_evaluation_function as evaluation
import mlflow
import pickle 
import json
from pathlib import Path

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment(experiment_name="technical_test")
with mlflow.start_run(run_name="model_training") as run:
    target_directory = (Path().cwd().parent / "data/03_model_inputs/")
    target_directory.mkdir(parents=True, exist_ok=True)

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Pre processing : Labels...")
    indexed_labels = preprocessing.set_index(data=labels)
    ml_labels = preprocessing.create_response_variable(labels = indexed_labels)
    LOGGER.info("Saving the final table...")
    ml_labels.to_parquet((target_directory / "ml_labels.parquet").as_posix())

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Pre processing : Instances...")
    indexed_instances = preprocessing.set_index(data=instances)
    instances_without_useless_columns = preprocessing.remove_unused_columns(
        data=indexed_instances, 
        columns_to_remove = columns_to_remove
    )
    mlflow.log_param(key = "columns_to_remove", value=columns_to_remove)
    typed_instances = preprocessing.set_features_type(
        data = instances_without_useless_columns, 
        features_type_mapping = features_type_mapping
    )
    mlflow.log_param(key = "features_type_mapping", value=features_type_mapping)
    instances_without_missing_values = preprocessing.impute_missing_values(
        data = typed_instances,
        binary_columns_list = binary_columns_list
    )
    mlflow.log_param(key = "binary_columns_list", value=binary_columns_list)
    columns_order = preprocessing.fit_columns_order(data = instances_without_missing_values)
    with open((target_directory / "columns_order.pkl").as_posix(), "wb") as file:
        pickle.dump(columns_order, file)
    mlflow.log_artifact(
        local_path=(target_directory / "columns_order.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    instances_with_correct_columns_order = preprocessing.transform_columns_order(
        data = instances_without_missing_values,
        columns_order = columns_order
    )
    numerical_data, categorical_data = preprocessing.split_numeric_and_categorical_data(
        data=instances_with_correct_columns_order
    )

    encoder = preprocessing.fit_categorical_encoder(
        data = categorical_data, 
        unknown_value = unknown_value
    )
    with open((target_directory / "encoder.pkl").as_posix(), "wb") as file:
        pickle.dump(encoder, file)
    mlflow.log_artifact(
        local_path=(target_directory / "encoder.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    encoded_categorical_data = preprocessing.transform_categorical_encoder(
        data = categorical_data,
        encoder = encoder 
    )

    ml_features = preprocessing.concatenate_numerical_and_categorical_data(
        numerical_data = numerical_data,
        categorical_data = encoded_categorical_data
    )
    LOGGER.info("Saving the final table...")
    ml_features.to_parquet((target_directory / "ml_features.parquet").as_posix())


    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Training the model...")
    x_train, x_test, y_train, y_test = ml_training.apply_train_test_split(
        x = ml_features, 
        y= ml_labels,
        test_size = test_size,
        shuffle = shuffle, 
        random_state = random_state
    )
    mlflow.log_param(key="test_size", value=test_size)
    mlflow.log_param(key="shuffle", value=shuffle)
    mlflow.log_param(key="random_state", value=random_state)

    xgb_model = ml_training.train_xgb_model(
        x_train = x_train,
        x_test = x_test,
        y_train = y_train,
        y_test = y_test,
        hyperparameters = hyperparameters,
        training_params = training_params,
    )
    mlflow.log_params(hyperparameters)
    mlflow.log_params(training_params)
    with open((target_directory / "xgb_model.pkl").as_posix(), "wb") as file:
        pickle.dump(xgb_model, file)
    mlflow.log_artifact(
        local_path=(target_directory / "xgb_model.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Explaining the model...")
    target_directory = (Path().cwd().parent / "data/04_model_outputs/")
    target_directory.mkdir(parents=True, exist_ok=True)
    shap_values_train = explanation.create_shap_values(
        data = x_train,
        model = xgb_model
    )
    importance_variables_plot = explanation.plot_importance_variables(
        model=xgb_model,
        data=x_train
    )
    importance_variables_plot.savefig(
        (target_directory / "importance_variables_xgb.png").as_posix(),  
        bbox_inches="tight"
    )
    mlflow.log_artifact(
        local_path=(target_directory / "importance_variables_xgb.png").as_posix(), 
        artifact_path="model_explanation"
    )

    dependence_plots = explanation.plot_dependence_plots(
        data=x_train,
        shap_values = shap_values_train,
        encoder=encoder
    )
    for key, value in dependence_plots.items():
        filepath = (target_directory / "dependence_plots")
        filepath.mkdir(parents=True, exist_ok=True)
        value.savefig(
            (filepath / key).as_posix(),  
            bbox_inches="tight"
        )
        mlflow.log_artifact(
            local_path=(filepath / key).as_posix(), 
            artifact_path="model_explanation"
        )

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Evaluating the model...")
    y_probs_test = prediction.predict_probs(data=x_test, model=xgb_model)
    classification_reports = evaluation.create_classification_reports(
        y_true=y_test, y_probs= y_probs_test, thresholds = [0.25,0.3,0.4,0.5,0.6]
    )
    with open((target_directory / "classification_reports.json").as_posix(), "w") as file :
        json.dump(classification_reports, file)
    mlflow.log_artifact(
        local_path=(target_directory / "classification_reports.json").as_posix(), 
        artifact_path="model_evaluation"
    )
# Out:
# 2025-07-13 10:44:35,029 : INFO : -------------------------------------------------
# 2025-07-13 10:44:35,029 : INFO : Pre processing : Labels...
# 2025-07-13 10:44:35,029 : INFO : labels.tp_fraud.value_counts().to_dict() = {0.0: 753, 1.0: 247}
# 2025-07-13 10:44:35,029 : INFO : Saving the final table...
# 2025-07-13 10:44:35,048 : INFO : -------------------------------------------------
# 2025-07-13 10:44:35,048 : INFO : Pre processing : Instances...
# 2025-07-13 10:44:35,124 : INFO : numerical_data.columns = Index(['vehicle_claim', 'number_of_vehicles_involved', 'policy_annual_premium',
#        'months_as_customer', 'capital-loss', 'capital-gains',
#        'bodily_injuries', 'property_claim',
#        'nb_years_between_incident_and_bind_date', 'per_person_limit',
#        'policy_deductable', 'auto_year', 'incident_hour_of_the_day',
#        'witnesses', 'age', 'umbrella_limit', 'insured_zip', 'injury_claim',
#        'per_accident_limit'],
#       dtype='object')
# 2025-07-13 10:44:35,124 : INFO : categorical_data.columns = Index(['incident_type', 'property_damage', 'authorities_contacted',
#        'policy_state', 'insured_education_level', 'police_report_available',
#        'insured_hobbies', 'incident_severity', 'insured_occupation',
#        'incident_state', 'incident_city', 'auto_make', 'collision_type'],
#       dtype='object')
# 2025-07-13 10:44:35,158 : INFO : Saving the final table...
# 2025-07-13 10:44:35,166 : INFO : -------------------------------------------------
# 2025-07-13 10:44:35,167 : INFO : Training the model...
# [0]	validation_0-auc:0.90748	validation_0-logloss:0.61787
# [1]	validation_0-auc:0.91791	validation_0-logloss:0.61277
# [2]	validation_0-auc:0.91733	validation_0-logloss:0.60786
# [3]	validation_0-auc:0.92334	validation_0-logloss:0.60417
# [4]	validation_0-auc:0.92151	validation_0-logloss:0.60006
# [5]	validation_0-auc:0.94710	validation_0-logloss:0.59808
# [6]	validation_0-auc:0.94828	validation_0-logloss:0.59325
# [7]	validation_0-auc:0.95017	validation_0-logloss:0.58857
# [8]	validation_0-auc:0.94799	validation_0-logloss:0.58857
# [9]	validation_0-auc:0.94598	validation_0-logloss:0.58806
# [10]	validation_0-auc:0.94870	validation_0-logloss:0.58377
# [11]	validation_0-auc:0.94834	validation_0-logloss:0.58211
# [12]	validation_0-auc:0.94905	validation_0-logloss:0.57838
# [13]	validation_0-auc:0.94693	validation_0-logloss:0.57449
# [14]	validation_0-auc:0.94351	validation_0-logloss:0.57476
# [15]	validation_0-auc:0.94374	validation_0-logloss:0.57390
# [16]	validation_0-auc:0.94245	validation_0-logloss:0.56988
# [17]	validation_0-auc:0.94256	validation_0-logloss:0.56744
# [18]	validation_0-auc:0.94245	validation_0-logloss:0.56427
# [19]	validation_0-auc:0.93832	validation_0-logloss:0.56406
# [20]	validation_0-auc:0.93926	validation_0-logloss:0.56048
# [21]	validation_0-auc:0.93796	validation_0-logloss:0.55766
# [22]	validation_0-auc:0.93867	validation_0-logloss:0.55638
# [23]	validation_0-auc:0.93714	validation_0-logloss:0.55288
# [24]	validation_0-auc:0.93643	validation_0-logloss:0.55181
# [25]	validation_0-auc:0.93749	validation_0-logloss:0.55172
# [26]	validation_0-auc:0.93631	validation_0-logloss:0.54884
# [27]	validation_0-auc:0.93832	validation_0-logloss:0.54857
# [28]	validation_0-auc:0.93855	validation_0-logloss:0.54568
# [29]	validation_0-auc:0.93714	validation_0-logloss:0.54255
# [30]	validation_0-auc:0.93537	validation_0-logloss:0.54103
# [31]	validation_0-auc:0.93502	validation_0-logloss:0.54102
# [32]	validation_0-auc:0.93372	validation_0-logloss:0.53995
# [33]	validation_0-auc:0.93348	validation_0-logloss:0.53815
# [34]	validation_0-auc:0.93313	validation_0-logloss:0.53549
# [35]	validation_0-auc:0.93561	validation_0-logloss:0.53473
# [36]	validation_0-auc:0.93631	validation_0-logloss:0.53477
# [37]	validation_0-auc:0.93667	validation_0-logloss:0.53468
# [38]	validation_0-auc:0.93678	validation_0-logloss:0.53445
# [39]	validation_0-auc:0.93631	validation_0-logloss:0.53123
# [40]	validation_0-auc:0.93561	validation_0-logloss:0.52874
# [41]	validation_0-auc:0.93608	validation_0-logloss:0.52793
# [42]	validation_0-auc:0.93655	validation_0-logloss:0.52505
# [43]	validation_0-auc:0.93690	validation_0-logloss:0.52459
# [44]	validation_0-auc:0.93749	validation_0-logloss:0.52311
# [45]	validation_0-auc:0.93655	validation_0-logloss:0.52195
# [46]	validation_0-auc:0.93655	validation_0-logloss:0.51909
# [47]	validation_0-auc:0.93643	validation_0-logloss:0.51628
# [48]	validation_0-auc:0.93572	validation_0-logloss:0.51485
# [49]	validation_0-auc:0.93737	validation_0-logloss:0.51198
# [50]	validation_0-auc:0.93726	validation_0-logloss:0.50921
# [51]	validation_0-auc:0.93584	validation_0-logloss:0.50717
# [52]	validation_0-auc:0.93443	validation_0-logloss:0.50515
# [53]	validation_0-auc:0.93419	validation_0-logloss:0.50263
# [54]	validation_0-auc:0.93608	validation_0-logloss:0.50193
# [55]	validation_0-auc:0.93537	validation_0-logloss:0.49946
# [56]	validation_0-auc:0.93513	validation_0-logloss:0.49736
# [57]	validation_0-auc:0.93372	validation_0-logloss:0.49557
# [58]	validation_0-auc:0.93325	validation_0-logloss:0.49498
# [59]	validation_0-auc:0.93348	validation_0-logloss:0.49474
# [60]	validation_0-auc:0.93336	validation_0-logloss:0.49252
# [61]	validation_0-auc:0.93372	validation_0-logloss:0.49127
# [62]	validation_0-auc:0.93513	validation_0-logloss:0.49116
# [63]	validation_0-auc:0.93572	validation_0-logloss:0.48896
# [64]	validation_0-auc:0.93466	validation_0-logloss:0.48818
# [65]	validation_0-auc:0.93490	validation_0-logloss:0.48830
# [66]	validation_0-auc:0.93466	validation_0-logloss:0.48839
# [67]	validation_0-auc:0.93407	validation_0-logloss:0.48632
# [68]	validation_0-auc:0.93502	validation_0-logloss:0.48378
# [69]	validation_0-auc:0.93525	validation_0-logloss:0.48323
# [70]	validation_0-auc:0.93525	validation_0-logloss:0.48122
# [71]	validation_0-auc:0.93443	validation_0-logloss:0.48045
# [72]	validation_0-auc:0.93372	validation_0-logloss:0.47853
# [73]	validation_0-auc:0.93407	validation_0-logloss:0.47631
# [74]	validation_0-auc:0.93431	validation_0-logloss:0.47452
# [75]	validation_0-auc:0.93407	validation_0-logloss:0.47342
# [76]	validation_0-auc:0.93384	validation_0-logloss:0.47264
# [77]	validation_0-auc:0.93289	validation_0-logloss:0.47277
# [78]	validation_0-auc:0.93289	validation_0-logloss:0.47077
# [79]	validation_0-auc:0.93278	validation_0-logloss:0.46887
# [80]	validation_0-auc:0.93301	validation_0-logloss:0.46842
# [81]	validation_0-auc:0.93266	validation_0-logloss:0.46761
# [82]	validation_0-auc:0.93289	validation_0-logloss:0.46643
# [83]	validation_0-auc:0.93230	validation_0-logloss:0.46637
# [84]	validation_0-auc:0.93278	validation_0-logloss:0.46427
# [85]	validation_0-auc:0.93301	validation_0-logloss:0.46322
# [86]	validation_0-auc:0.93360	validation_0-logloss:0.46172
# [87]	validation_0-auc:0.93289	validation_0-logloss:0.46105
# [88]	validation_0-auc:0.93313	validation_0-logloss:0.45922
# [89]	validation_0-auc:0.93313	validation_0-logloss:0.45750
# [90]	validation_0-auc:0.93301	validation_0-logloss:0.45716
# [91]	validation_0-auc:0.93360	validation_0-logloss:0.45673
# [92]	validation_0-auc:0.93360	validation_0-logloss:0.45464
# [93]	validation_0-auc:0.93360	validation_0-logloss:0.45403
# [94]	validation_0-auc:0.93230	validation_0-logloss:0.45437
# [95]	validation_0-auc:0.93195	validation_0-logloss:0.45450
# [96]	validation_0-auc:0.93171	validation_0-logloss:0.45296
# [97]	validation_0-auc:0.93148	validation_0-logloss:0.45223
# [98]	validation_0-auc:0.93219	validation_0-logloss:0.45082
# [99]	validation_0-auc:0.93219	validation_0-logloss:0.45067
# [100]	validation_0-auc:0.93266	validation_0-logloss:0.44830
# [101]	validation_0-auc:0.93230	validation_0-logloss:0.44836
# [102]	validation_0-auc:0.93230	validation_0-logloss:0.44687
# [103]	validation_0-auc:0.93183	validation_0-logloss:0.44553
# [104]	validation_0-auc:0.93089	validation_0-logloss:0.44403
# [105]	validation_0-auc:0.93101	validation_0-logloss:0.44246
# [106]	validation_0-auc:0.93112	validation_0-logloss:0.44116
# [107]	validation_0-auc:0.93089	validation_0-logloss:0.43986
# [108]	validation_0-auc:0.93053	validation_0-logloss:0.43849
# [109]	validation_0-auc:0.93065	validation_0-logloss:0.43718
# [110]	validation_0-auc:0.93030	validation_0-logloss:0.43667
# [111]	validation_0-auc:0.92983	validation_0-logloss:0.43521
# [112]	validation_0-auc:0.93006	validation_0-logloss:0.43394
# [113]	validation_0-auc:0.92994	validation_0-logloss:0.43263
# [114]	validation_0-auc:0.93030	validation_0-logloss:0.43110
# [115]	validation_0-auc:0.93053	validation_0-logloss:0.42991
# [116]	validation_0-auc:0.93053	validation_0-logloss:0.42861
# [117]	validation_0-auc:0.93018	validation_0-logloss:0.42740
# [118]	validation_0-auc:0.93042	validation_0-logloss:0.42689
# [119]	validation_0-auc:0.93053	validation_0-logloss:0.42558
# [120]	validation_0-auc:0.92983	validation_0-logloss:0.42421
# [121]	validation_0-auc:0.93006	validation_0-logloss:0.42422
# [122]	validation_0-auc:0.93018	validation_0-logloss:0.42428
# [123]	validation_0-auc:0.93065	validation_0-logloss:0.42271
# [124]	validation_0-auc:0.93018	validation_0-logloss:0.42247
# [125]	validation_0-auc:0.93089	validation_0-logloss:0.42233
# [126]	validation_0-auc:0.93053	validation_0-logloss:0.42099
# [127]	validation_0-auc:0.93207	validation_0-logloss:0.42017
# [128]	validation_0-auc:0.93089	validation_0-logloss:0.41940
# [129]	validation_0-auc:0.93101	validation_0-logloss:0.41891
# [130]	validation_0-auc:0.93112	validation_0-logloss:0.41884
# [131]	validation_0-auc:0.93112	validation_0-logloss:0.41753
# [132]	validation_0-auc:0.93183	validation_0-logloss:0.41779
# [133]	validation_0-auc:0.93160	validation_0-logloss:0.41792
# [134]	validation_0-auc:0.93207	validation_0-logloss:0.41702
# [135]	validation_0-auc:0.93207	validation_0-logloss:0.41638
# [136]	validation_0-auc:0.93171	validation_0-logloss:0.41553
# [137]	validation_0-auc:0.93219	validation_0-logloss:0.41532
# [138]	validation_0-auc:0.93195	validation_0-logloss:0.41435
# [139]	validation_0-auc:0.93207	validation_0-logloss:0.41328
# [140]	validation_0-auc:0.93183	validation_0-logloss:0.41321
# [141]	validation_0-auc:0.93171	validation_0-logloss:0.41211
# [142]	validation_0-auc:0.93195	validation_0-logloss:0.41251
# [143]	validation_0-auc:0.93195	validation_0-logloss:0.41237
# [144]	validation_0-auc:0.93124	validation_0-logloss:0.41217
# [145]	validation_0-auc:0.93089	validation_0-logloss:0.41102
# [146]	validation_0-auc:0.93065	validation_0-logloss:0.41088
# [147]	validation_0-auc:0.93136	validation_0-logloss:0.41055
# [148]	validation_0-auc:0.93065	validation_0-logloss:0.40927
# [149]	validation_0-auc:0.93030	validation_0-logloss:0.40919
# [150]	validation_0-auc:0.93030	validation_0-logloss:0.40792
# [151]	validation_0-auc:0.93042	validation_0-logloss:0.40748
# [152]	validation_0-auc:0.93053	validation_0-logloss:0.40703
# [153]	validation_0-auc:0.93089	validation_0-logloss:0.40670
# [154]	validation_0-auc:0.93042	validation_0-logloss:0.40569
# [155]	validation_0-auc:0.93053	validation_0-logloss:0.40489
# [156]	validation_0-auc:0.93030	validation_0-logloss:0.40410
# [157]	validation_0-auc:0.93065	validation_0-logloss:0.40395
# [158]	validation_0-auc:0.93101	validation_0-logloss:0.40376
# [159]	validation_0-auc:0.93006	validation_0-logloss:0.40336
# [160]	validation_0-auc:0.92971	validation_0-logloss:0.40296
# [161]	validation_0-auc:0.93018	validation_0-logloss:0.40262
# [162]	validation_0-auc:0.93042	validation_0-logloss:0.40173
# [163]	validation_0-auc:0.93030	validation_0-logloss:0.40193
# [164]	validation_0-auc:0.93006	validation_0-logloss:0.40219
# [165]	validation_0-auc:0.92994	validation_0-logloss:0.40137
# [166]	validation_0-auc:0.92959	validation_0-logloss:0.40111
# [167]	validation_0-auc:0.92865	validation_0-logloss:0.40063
# [168]	validation_0-auc:0.92971	validation_0-logloss:0.40034
# [169]	validation_0-auc:0.92924	validation_0-logloss:0.40075
# [170]	validation_0-auc:0.92912	validation_0-logloss:0.40001
# [171]	validation_0-auc:0.92971	validation_0-logloss:0.39995
# [172]	validation_0-auc:0.92947	validation_0-logloss:0.39936
# [173]	validation_0-auc:0.93018	validation_0-logloss:0.39832
# [174]	validation_0-auc:0.93006	validation_0-logloss:0.39732
# [175]	validation_0-auc:0.92983	validation_0-logloss:0.39730
# [176]	validation_0-auc:0.92947	validation_0-logloss:0.39719
# [177]	validation_0-auc:0.92924	validation_0-logloss:0.39604
# [178]	validation_0-auc:0.92865	validation_0-logloss:0.39557
# [179]	validation_0-auc:0.92959	validation_0-logloss:0.39540
# [180]	validation_0-auc:0.92912	validation_0-logloss:0.39513
# [181]	validation_0-auc:0.92912	validation_0-logloss:0.39538
# [182]	validation_0-auc:0.92959	validation_0-logloss:0.39546
# [183]	validation_0-auc:0.92924	validation_0-logloss:0.39552
# [184]	validation_0-auc:0.92877	validation_0-logloss:0.39538
# [185]	validation_0-auc:0.92829	validation_0-logloss:0.39515
# [186]	validation_0-auc:0.92794	validation_0-logloss:0.39433
# [187]	validation_0-auc:0.92759	validation_0-logloss:0.39443
# [188]	validation_0-auc:0.92759	validation_0-logloss:0.39379
# [189]	validation_0-auc:0.92806	validation_0-logloss:0.39338
# [190]	validation_0-auc:0.92688	validation_0-logloss:0.39277
# [191]	validation_0-auc:0.92688	validation_0-logloss:0.39308
# [192]	validation_0-auc:0.92700	validation_0-logloss:0.39240
# [193]	validation_0-auc:0.92818	validation_0-logloss:0.39155
# [194]	validation_0-auc:0.92759	validation_0-logloss:0.39127
# [195]	validation_0-auc:0.92688	validation_0-logloss:0.39089
# [196]	validation_0-auc:0.92664	validation_0-logloss:0.39029
# [197]	validation_0-auc:0.92629	validation_0-logloss:0.38958
# [198]	validation_0-auc:0.92641	validation_0-logloss:0.38912
# [199]	validation_0-auc:0.92641	validation_0-logloss:0.38820
# [200]	validation_0-auc:0.92617	validation_0-logloss:0.38739
# [201]	validation_0-auc:0.92617	validation_0-logloss:0.38663
# [202]	validation_0-auc:0.92617	validation_0-logloss:0.38637
# [203]	validation_0-auc:0.92652	validation_0-logloss:0.38624
# [204]	validation_0-auc:0.92605	validation_0-logloss:0.38550
# [205]	validation_0-auc:0.92546	validation_0-logloss:0.38532
# [206]	validation_0-auc:0.92570	validation_0-logloss:0.38522
# [207]	validation_0-auc:0.92534	validation_0-logloss:0.38535
# [208]	validation_0-auc:0.92629	validation_0-logloss:0.38449
# [209]	validation_0-auc:0.92652	validation_0-logloss:0.38450
# [210]	validation_0-auc:0.92605	validation_0-logloss:0.38385
# [211]	validation_0-auc:0.92641	validation_0-logloss:0.38324
# [212]	validation_0-auc:0.92723	validation_0-logloss:0.38316
# [213]	validation_0-auc:0.92735	validation_0-logloss:0.38223
# [214]	validation_0-auc:0.92688	validation_0-logloss:0.38231
# [215]	validation_0-auc:0.92688	validation_0-logloss:0.38258
# [216]	validation_0-auc:0.92676	validation_0-logloss:0.38198
# [217]	validation_0-auc:0.92593	validation_0-logloss:0.38221
# [218]	validation_0-auc:0.92617	validation_0-logloss:0.38154
# [219]	validation_0-auc:0.92676	validation_0-logloss:0.38133
# [220]	validation_0-auc:0.92700	validation_0-logloss:0.38075
# [221]	validation_0-auc:0.92676	validation_0-logloss:0.38071
# [222]	validation_0-auc:0.92700	validation_0-logloss:0.38076
# [223]	validation_0-auc:0.92700	validation_0-logloss:0.38027
# [224]	validation_0-auc:0.92723	validation_0-logloss:0.38043
# [225]	validation_0-auc:0.92700	validation_0-logloss:0.38068
# [226]	validation_0-auc:0.92688	validation_0-logloss:0.37994
# [227]	validation_0-auc:0.92723	validation_0-logloss:0.37914
# [228]	validation_0-auc:0.92700	validation_0-logloss:0.37831
# [229]	validation_0-auc:0.92735	validation_0-logloss:0.37815
# [230]	validation_0-auc:0.92747	validation_0-logloss:0.37757
# [231]	validation_0-auc:0.92759	validation_0-logloss:0.37705
# [232]	validation_0-auc:0.92747	validation_0-logloss:0.37701
# [233]	validation_0-auc:0.92735	validation_0-logloss:0.37652
# [234]	validation_0-auc:0.92770	validation_0-logloss:0.37624
# [235]	validation_0-auc:0.92747	validation_0-logloss:0.37590
# [236]	validation_0-auc:0.92723	validation_0-logloss:0.37566
# [237]	validation_0-auc:0.92806	validation_0-logloss:0.37571
# [238]	validation_0-auc:0.92829	validation_0-logloss:0.37556
# [239]	validation_0-auc:0.92853	validation_0-logloss:0.37496
# [240]	validation_0-auc:0.92877	validation_0-logloss:0.37462
# [241]	validation_0-auc:0.92853	validation_0-logloss:0.37466
# [242]	validation_0-auc:0.92829	validation_0-logloss:0.37443
# [243]	validation_0-auc:0.92829	validation_0-logloss:0.37394
# [244]	validation_0-auc:0.92806	validation_0-logloss:0.37324
# [245]	validation_0-auc:0.92747	validation_0-logloss:0.37289
# [246]	validation_0-auc:0.92723	validation_0-logloss:0.37243
# [247]	validation_0-auc:0.92735	validation_0-logloss:0.37170
# [248]	validation_0-auc:0.92770	validation_0-logloss:0.37124
# [249]	validation_0-auc:0.92794	validation_0-logloss:0.37064
# [250]	validation_0-auc:0.92794	validation_0-logloss:0.37049
# [251]	validation_0-auc:0.92759	validation_0-logloss:0.36987
# [252]	validation_0-auc:0.92794	validation_0-logloss:0.36951
# [253]	validation_0-auc:0.92747	validation_0-logloss:0.36908
# [254]	validation_0-auc:0.92759	validation_0-logloss:0.36908
# [255]	validation_0-auc:0.92711	validation_0-logloss:0.36929
# [256]	validation_0-auc:0.92735	validation_0-logloss:0.36857
# [257]	validation_0-auc:0.92770	validation_0-logloss:0.36853
# [258]	validation_0-auc:0.92806	validation_0-logloss:0.36817
# [259]	validation_0-auc:0.92818	validation_0-logloss:0.36802
# [260]	validation_0-auc:0.92818	validation_0-logloss:0.36807
# [261]	validation_0-auc:0.92877	validation_0-logloss:0.36789
# [262]	validation_0-auc:0.92829	validation_0-logloss:0.36756
# [263]	validation_0-auc:0.92806	validation_0-logloss:0.36698
# [264]	validation_0-auc:0.92853	validation_0-logloss:0.36700
# [265]	validation_0-auc:0.92888	validation_0-logloss:0.36679
# [266]	validation_0-auc:0.92853	validation_0-logloss:0.36647
# [267]	validation_0-auc:0.92818	validation_0-logloss:0.36606
# [268]	validation_0-auc:0.92818	validation_0-logloss:0.36564
# [269]	validation_0-auc:0.92818	validation_0-logloss:0.36534
# [270]	validation_0-auc:0.92770	validation_0-logloss:0.36519
# [271]	validation_0-auc:0.92770	validation_0-logloss:0.36521
# [272]	validation_0-auc:0.92794	validation_0-logloss:0.36505
# [273]	validation_0-auc:0.92782	validation_0-logloss:0.36442
# [274]	validation_0-auc:0.92806	validation_0-logloss:0.36446
# [275]	validation_0-auc:0.92770	validation_0-logloss:0.36404
# [276]	validation_0-auc:0.92806	validation_0-logloss:0.36348
# [277]	validation_0-auc:0.92747	validation_0-logloss:0.36314
# [278]	validation_0-auc:0.92759	validation_0-logloss:0.36250
# [279]	validation_0-auc:0.92747	validation_0-logloss:0.36228
# [280]	validation_0-auc:0.92711	validation_0-logloss:0.36207
# [281]	validation_0-auc:0.92735	validation_0-logloss:0.36163
# [282]	validation_0-auc:0.92759	validation_0-logloss:0.36152
# [283]	validation_0-auc:0.92770	validation_0-logloss:0.36136
# [284]	validation_0-auc:0.92782	validation_0-logloss:0.36098
# [285]	validation_0-auc:0.92759	validation_0-logloss:0.36058
# [286]	validation_0-auc:0.92735	validation_0-logloss:0.36006
# [287]	validation_0-auc:0.92747	validation_0-logloss:0.36012
# [288]	validation_0-auc:0.92782	validation_0-logloss:0.35968
# [289]	validation_0-auc:0.92782	validation_0-logloss:0.35951
# [290]	validation_0-auc:0.92759	validation_0-logloss:0.35960
# [291]	validation_0-auc:0.92770	validation_0-logloss:0.35907
# [292]	validation_0-auc:0.92782	validation_0-logloss:0.35897
# [293]	validation_0-auc:0.92759	validation_0-logloss:0.35884
# [294]	validation_0-auc:0.92794	validation_0-logloss:0.35833
# [295]	validation_0-auc:0.92794	validation_0-logloss:0.35803
# [296]	validation_0-auc:0.92818	validation_0-logloss:0.35774
# [297]	validation_0-auc:0.92841	validation_0-logloss:0.35774
# [298]	validation_0-auc:0.92853	validation_0-logloss:0.35754
# [299]	validation_0-auc:0.92829	validation_0-logloss:0.35784
# [300]	validation_0-auc:0.92841	validation_0-logloss:0.35728
# [301]	validation_0-auc:0.92853	validation_0-logloss:0.35723
# [302]	validation_0-auc:0.92806	validation_0-logloss:0.35726
# [303]	validation_0-auc:0.92818	validation_0-logloss:0.35719
# [304]	validation_0-auc:0.92818	validation_0-logloss:0.35674
# [305]	validation_0-auc:0.92818	validation_0-logloss:0.35675
# [306]	validation_0-auc:0.92782	validation_0-logloss:0.35700
# [307]	validation_0-auc:0.92829	validation_0-logloss:0.35672
# [308]	validation_0-auc:0.92806	validation_0-logloss:0.35675
# [309]	validation_0-auc:0.92806	validation_0-logloss:0.35669
# [310]	validation_0-auc:0.92806	validation_0-logloss:0.35668
# [311]	validation_0-auc:0.92782	validation_0-logloss:0.35655
# [312]	validation_0-auc:0.92818	validation_0-logloss:0.35589
# [313]	validation_0-auc:0.92818	validation_0-logloss:0.35576
# [314]	validation_0-auc:0.92806	validation_0-logloss:0.35583
# [315]	validation_0-auc:0.92770	validation_0-logloss:0.35534
# [316]	validation_0-auc:0.92782	validation_0-logloss:0.35554
# [317]	validation_0-auc:0.92759	validation_0-logloss:0.35535
# [318]	validation_0-auc:0.92759	validation_0-logloss:0.35479
# [319]	validation_0-auc:0.92735	validation_0-logloss:0.35462
# [320]	validation_0-auc:0.92735	validation_0-logloss:0.35427
# [321]	validation_0-auc:0.92747	validation_0-logloss:0.35397
# [322]	validation_0-auc:0.92759	validation_0-logloss:0.35375
# [323]	validation_0-auc:0.92782	validation_0-logloss:0.35390
# [324]	validation_0-auc:0.92794	validation_0-logloss:0.35336
# [325]	validation_0-auc:0.92770	validation_0-logloss:0.35328
# [326]	validation_0-auc:0.92759	validation_0-logloss:0.35315
# [327]	validation_0-auc:0.92794	validation_0-logloss:0.35305
# [328]	validation_0-auc:0.92818	validation_0-logloss:0.35281
# [329]	validation_0-auc:0.92794	validation_0-logloss:0.35306
# [330]	validation_0-auc:0.92759	validation_0-logloss:0.35276
# [331]	validation_0-auc:0.92829	validation_0-logloss:0.35284
# [332]	validation_0-auc:0.92818	validation_0-logloss:0.35283
# [333]	validation_0-auc:0.92829	validation_0-logloss:0.35290
# [334]	validation_0-auc:0.92818	validation_0-logloss:0.35315
# [335]	validation_0-auc:0.92841	validation_0-logloss:0.35284
# [336]	validation_0-auc:0.92806	validation_0-logloss:0.35257
# [337]	validation_0-auc:0.92794	validation_0-logloss:0.35272
# [338]	validation_0-auc:0.92782	validation_0-logloss:0.35234
# [339]	validation_0-auc:0.92723	validation_0-logloss:0.35260
# [340]	validation_0-auc:0.92770	validation_0-logloss:0.35239
# [341]	validation_0-auc:0.92770	validation_0-logloss:0.35210
# [342]	validation_0-auc:0.92759	validation_0-logloss:0.35203
# [343]	validation_0-auc:0.92723	validation_0-logloss:0.35226
# [344]	validation_0-auc:0.92759	validation_0-logloss:0.35192
# [345]	validation_0-auc:0.92700	validation_0-logloss:0.35202
# [346]	validation_0-auc:0.92735	validation_0-logloss:0.35156
# [347]	validation_0-auc:0.92723	validation_0-logloss:0.35145
# [348]	validation_0-auc:0.92711	validation_0-logloss:0.35132
# [349]	validation_0-auc:0.92735	validation_0-logloss:0.35139
# [350]	validation_0-auc:0.92747	validation_0-logloss:0.35101
# [351]	validation_0-auc:0.92735	validation_0-logloss:0.35092
# [352]	validation_0-auc:0.92711	validation_0-logloss:0.35084
# [353]	validation_0-auc:0.92735	validation_0-logloss:0.35039
# [354]	validation_0-auc:0.92688	validation_0-logloss:0.35025
# [355]	validation_0-auc:0.92759	validation_0-logloss:0.34998
# [356]	validation_0-auc:0.92723	validation_0-logloss:0.34969
# [357]	validation_0-auc:0.92759	validation_0-logloss:0.34972
# [358]	validation_0-auc:0.92723	validation_0-logloss:0.34930
# [359]	validation_0-auc:0.92688	validation_0-logloss:0.34951
# [360]	validation_0-auc:0.92723	validation_0-logloss:0.34918
# [361]	validation_0-auc:0.92700	validation_0-logloss:0.34934
# [362]	validation_0-auc:0.92700	validation_0-logloss:0.34889
# [363]	validation_0-auc:0.92735	validation_0-logloss:0.34874
# [364]	validation_0-auc:0.92700	validation_0-logloss:0.34878
# [365]	validation_0-auc:0.92700	validation_0-logloss:0.34891
# [366]	validation_0-auc:0.92688	validation_0-logloss:0.34895
# [367]	validation_0-auc:0.92723	validation_0-logloss:0.34863
# [368]	validation_0-auc:0.92770	validation_0-logloss:0.34858
# [369]	validation_0-auc:0.92688	validation_0-logloss:0.34864
# [370]	validation_0-auc:0.92664	validation_0-logloss:0.34858
# [371]	validation_0-auc:0.92641	validation_0-logloss:0.34847
# [372]	validation_0-auc:0.92652	validation_0-logloss:0.34845
# [373]	validation_0-auc:0.92641	validation_0-logloss:0.34847
# [374]	validation_0-auc:0.92641	validation_0-logloss:0.34831
# [375]	validation_0-auc:0.92664	validation_0-logloss:0.34814
# [376]	validation_0-auc:0.92676	validation_0-logloss:0.34768
# [377]	validation_0-auc:0.92676	validation_0-logloss:0.34750
# [378]	validation_0-auc:0.92711	validation_0-logloss:0.34771
# [379]	validation_0-auc:0.92700	validation_0-logloss:0.34763
# [380]	validation_0-auc:0.92700	validation_0-logloss:0.34772
# [381]	validation_0-auc:0.92711	validation_0-logloss:0.34755
# [382]	validation_0-auc:0.92747	validation_0-logloss:0.34749
# [383]	validation_0-auc:0.92747	validation_0-logloss:0.34720
# [384]	validation_0-auc:0.92735	validation_0-logloss:0.34733
# [385]	validation_0-auc:0.92735	validation_0-logloss:0.34711
# [386]	validation_0-auc:0.92723	validation_0-logloss:0.34696
# [387]	validation_0-auc:0.92759	validation_0-logloss:0.34680
# [388]	validation_0-auc:0.92770	validation_0-logloss:0.34666
# [389]	validation_0-auc:0.92723	validation_0-logloss:0.34682
# [390]	validation_0-auc:0.92782	validation_0-logloss:0.34641
# [391]	validation_0-auc:0.92759	validation_0-logloss:0.34642
# [392]	validation_0-auc:0.92770	validation_0-logloss:0.34637
# [393]	validation_0-auc:0.92759	validation_0-logloss:0.34596
# [394]	validation_0-auc:0.92770	validation_0-logloss:0.34584
# [395]	validation_0-auc:0.92759	validation_0-logloss:0.34597
# [396]	validation_0-auc:0.92759	validation_0-logloss:0.34582
# [397]	validation_0-auc:0.92770	validation_0-logloss:0.34586
# [398]	validation_0-auc:0.92759	validation_0-logloss:0.34572
# [399]	validation_0-auc:0.92747	validation_0-logloss:0.34578
# [400]	validation_0-auc:0.92770	validation_0-logloss:0.34546
# [401]	validation_0-auc:0.92735	validation_0-logloss:0.34554
# [402]	validation_0-auc:0.92735	validation_0-logloss:0.34529
# [403]	validation_0-auc:0.92735	validation_0-logloss:0.34545
# [404]	validation_0-auc:0.92735	validation_0-logloss:0.34549
# [405]	validation_0-auc:0.92700	validation_0-logloss:0.34541
# [406]	validation_0-auc:0.92688	validation_0-logloss:0.34551
# [407]	validation_0-auc:0.92676	validation_0-logloss:0.34564
# [408]	validation_0-auc:0.92676	validation_0-logloss:0.34596
# [409]	validation_0-auc:0.92700	validation_0-logloss:0.34571
# [410]	validation_0-auc:0.92676	validation_0-logloss:0.34579
# [411]	validation_0-auc:0.92676	validation_0-logloss:0.34561
# [412]	validation_0-auc:0.92652	validation_0-logloss:0.34545
# [413]	validation_0-auc:0.92629	validation_0-logloss:0.34541
# [414]	validation_0-auc:0.92652	validation_0-logloss:0.34532
# [415]	validation_0-auc:0.92641	validation_0-logloss:0.34522
# [416]	validation_0-auc:0.92641	validation_0-logloss:0.34527
# [417]	validation_0-auc:0.92652	validation_0-logloss:0.34521
# [418]	validation_0-auc:0.92711	validation_0-logloss:0.34493
# [419]	validation_0-auc:0.92688	validation_0-logloss:0.34475
# [420]	validation_0-auc:0.92676	validation_0-logloss:0.34445
# [421]	validation_0-auc:0.92629	validation_0-logloss:0.34450
# [422]	validation_0-auc:0.92641	validation_0-logloss:0.34469
# [423]	validation_0-auc:0.92652	validation_0-logloss:0.34471
# [424]	validation_0-auc:0.92688	validation_0-logloss:0.34454
# [425]	validation_0-auc:0.92676	validation_0-logloss:0.34441
# [426]	validation_0-auc:0.92629	validation_0-logloss:0.34458
# [427]	validation_0-auc:0.92641	validation_0-logloss:0.34444
# [428]	validation_0-auc:0.92641	validation_0-logloss:0.34449
# [429]	validation_0-auc:0.92593	validation_0-logloss:0.34446
# [430]	validation_0-auc:0.92605	validation_0-logloss:0.34448
# [431]	validation_0-auc:0.92617	validation_0-logloss:0.34425
# [432]	validation_0-auc:0.92582	validation_0-logloss:0.34414
# [433]	validation_0-auc:0.92593	validation_0-logloss:0.34429
# [434]	validation_0-auc:0.92593	validation_0-logloss:0.34432
# [435]	validation_0-auc:0.92605	validation_0-logloss:0.34433
# [436]	validation_0-auc:0.92617	validation_0-logloss:0.34432
# [437]	validation_0-auc:0.92617	validation_0-logloss:0.34400
# [438]	validation_0-auc:0.92593	validation_0-logloss:0.34382
# [439]	validation_0-auc:0.92570	validation_0-logloss:0.34390
# [440]	validation_0-auc:0.92570	validation_0-logloss:0.34365
# [441]	validation_0-auc:0.92570	validation_0-logloss:0.34402
# [442]	validation_0-auc:0.92523	validation_0-logloss:0.34399
# [443]	validation_0-auc:0.92499	validation_0-logloss:0.34391
# [444]	validation_0-auc:0.92476	validation_0-logloss:0.34386
# [445]	validation_0-auc:0.92476	validation_0-logloss:0.34369
# [446]	validation_0-auc:0.92499	validation_0-logloss:0.34374
# [447]	validation_0-auc:0.92523	validation_0-logloss:0.34377
# [448]	validation_0-auc:0.92546	validation_0-logloss:0.34375
# [449]	validation_0-auc:0.92558	validation_0-logloss:0.34374
# [450]	validation_0-auc:0.92558	validation_0-logloss:0.34383
# [451]	validation_0-auc:0.92558	validation_0-logloss:0.34388
# [452]	validation_0-auc:0.92558	validation_0-logloss:0.34396
# [453]	validation_0-auc:0.92523	validation_0-logloss:0.34400
# [454]	validation_0-auc:0.92487	validation_0-logloss:0.34419
# [455]	validation_0-auc:0.92511	validation_0-logloss:0.34395
# 2025-07-13 10:44:47,454 : INFO : -------------------------------------------------
# 2025-07-13 10:44:47,454 : INFO : Explaining the model...
# 2025-07-13 10:44:53,268 : INFO : -------------------------------------------------
# 2025-07-13 10:44:53,269 : INFO : Evaluating the model...
# 🏃 View run model_training at: http://localhost:5000/#/experiments/222123412902236260/runs/d5c16460cd444b2b938c4086412590de
# 🧪 View experiment at: http://localhost:5000/#/experiments/222123412902236260

# %% [markdown]
# # **Conclusions & more**
#
# - the idea was to predict the probability of fraud and then choose a threshold to determine wether a predicted individual is a fraud or not
# - the problem was a binary classification with imbalanced classes so it is better to do so instead of predicting the class directly (most of the time the threshold is fixed at 50% so with an imbalanced classification the true positives will likely stay at 0)
# - what metrics did I choose during model training ? : minimizing the log loss
#     - for an imbalanced classification, it is better to predict probabilities and then choose a threshold (every probs >= threshold will be considered as a fraud)
#     - the log loss is a "distance" between the labels and the predicted probabilities, so minimizing it will help calibrate the model
# - what metrics did I choose to evaluate the model ? :
#     - precision
#     - recall
#     - the confusion matrix
# - these are the prefered metrics in this case because :
#     - for fraud detection what matters the most is the nb of fraud detected and the amount of cases the model predicts as a high risk of fraud
#     - for an imbalanced classification problem looking at the accuracy is not advised (if i only have 5% of 1 in my labels, by predicting everyone to 0 i will have a 95% accuracy)
# - what are the results ? :
#
#     - when grouping high cardinality categorical variables :
# ```json
# {
#     "classification_report_threshold_25%": {
#         "precision": 0.6774193548387096,
#         "recal": 0.6885245901639344,
#         "true_positives": 42.0,
#         "false_positives": 20.0,
#         "true_negatives": 119.0,
#         "false_negatives": 19.0
#     },
#     "classification_report_threshold_30%": {
#         "precision": 0.7272727272727273,
#         "recal": 0.6557377049180327,
#         "true_positives": 40.0,
#         "false_positives": 15.0,
#         "true_negatives": 124.0,
#         "false_negatives": 21.0
#     },
#     "classification_report_threshold_40%": {
#         "precision": 0.7391304347826086,
#         "recal": 0.5573770491803278,
#         "true_positives": 34.0,
#         "false_positives": 12.0,
#         "true_negatives": 127.0,
#         "false_negatives": 27.0
#     },
#     "classification_report_threshold_50%": {
#         "precision": 0.8484848484848485,
#         "recal": 0.45901639344262296,
#         "true_positives": 28.0,
#         "false_positives": 5.0,
#         "true_negatives": 134.0,
#         "false_negatives": 33.0
#     },
#     "classification_report_threshold_60%": {
#         "precision": 0.8666666666666667,
#         "recal": 0.21311475409836064,
#         "true_positives": 13.0,
#         "false_positives": 2.0,
#         "true_negatives": 137.0,
#         "false_negatives": 48.0
#     }
# }
# ```
#
#     - when not grouping high cardinality categorical variables :
#
# ```json
# {
#   "classification_report_threshold_25%": {
#     "precision": 0.7671232876712328,
#     "recal": 0.9180327868852459,
#     "true_positives": 56,
#     "false_positives": 17,
#     "true_negatives": 122,
#     "false_negatives": 5
#   },
#   "classification_report_threshold_30%": {
#     "precision": 0.7681159420289855,
#     "recal": 0.8688524590163934,
#     "true_positives": 53,
#     "false_positives": 16,
#     "true_negatives": 123,
#     "false_negatives": 8
#   },
#   "classification_report_threshold_40%": {
#     "precision": 0.7627118644067796,
#     "recal": 0.7377049180327869,
#     "true_positives": 45,
#     "false_positives": 14,
#     "true_negatives": 125,
#     "false_negatives": 16
#   },
#   "classification_report_threshold_50%": {
#     "precision": 0.7857142857142857,
#     "recal": 0.5409836065573771,
#     "true_positives": 33,
#     "false_positives": 9,
#     "true_negatives": 130,
#     "false_negatives": 28
#   },
#   "classification_report_threshold_60%": {
#     "precision": 0.8333333333333334,
#     "recal": 0.32786885245901637,
#     "true_positives": 20,
#     "false_positives": 4,
#     "true_negatives": 135,
#     "false_negatives": 41
#   }
# }
# ```
# - we observe a significant change in performance if we group the high cardinality variables or not -> we will choose not to
#     - the XGBoost can handle high cardinality variables when using OrdinalEncoder because it splits each node using a "question-based" threshold
#     - `feature_1 >= threshold ?`
# - the goal is to find a balance between precision and recall, we wan't to detect enough frauds but without making too much controls, fraud investigations are usually quite costly for insurance companies.
# - the great compromise in our case could be choosing a threshold around 25~30%
