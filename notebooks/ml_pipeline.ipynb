# %% [markdown]
# # **ML pipeline**
#
# - This notebook contains the pre-processing and the model training phase
# - Why grouping the 2 steps ?
#     - This phase contains all the 'fit' steps : we will fit the encoder and the model so that it can be used later on during inference
# - Choice of the model : why choosing XGBoost ?
#     - `Time` : we don't dispose of a lot of time to benchmark multiple algorithms so we need to make a choice
#     - `Performance` : XGBoost has proven to be the winning solution algorithm in numerous hackathons (kaggle,...)
#     - `Calibration` : easy to calibrate and allows the user to perform regularization and prevent overfitting
#     - `Scalability` : fast and consistent execution time even with large datasets
#     - `Explainability` : TreeSHAP algorithm is able to calculate very accurate SHAP values for tree-based models
#     - `Conveniency` : The tree-base nature of the model allows us to skip multiple pre-processing steps such as normalization, standardization & extreme values processing

# %%
import sys
from pathlib import Path
import logging 
import warnings
warnings.filterwarnings('ignore')

LOGGER = logging.getLogger(__name__)
sys.path.append(str(Path("../src").resolve())) 

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## **Parameters**

# %%
columns_to_remove = ["policy_bind_date", "incident_date", "total_claim_amount"]
features_type_mapping = {
    'policy_state': "str", 
    'insured_education_level': "str", 
    'insured_occupation': "str",
    'insured_hobbies': "str", 
    'incident_type': "str", 
    'collision_type': "str",
    'incident_severity': "str", 
    'authorities_contacted': "str", 
    'incident_state': "str",
    'incident_city': "str", 
    'property_damage': "str", 
    'police_report_available': "str",
    'auto_make': "str"
}
binary_columns_list = ["property_damage", "police_report_available"]
all_categorical_mappings = {
    "insured_occupation" :  {
        'machine-op-inspct': "workers", 
        'prof-specialty': "higher_professions", 
        'tech-support': "intermediate", 
        'sales': "intermediate", 
        'exec-managerial': "higher_professions", 
        'craft-repair': "craftmen_traders_entrepreneurs", 
        'transport-moving': "craftmen_traders_entrepreneurs", 
        'priv-house-serv': "employees", 
        'other-service': "employees", 
        'armed-forces': "military", 
        'adm-clerical': "intermediate", 
        'protective-serv': "intermediate", 
        'handlers-cleaners': "employees", 
        'farming-fishing': "agriculture"
    },
    "insured_hobbies" : {
        'reading': "intellectual_hobbies", 
        'exercise': "fitness_and_sports", 
        'paintball': "extreme_sports", 
        'bungie-jumping': "extreme_sports", 
        'movies': "entertainment", 
        'camping': "outdoor", 
        'golf': "premium_hobbies", 
        'kayaking': "outdoor", 
        'yachting': "premium_hobbies", 
        'hiking': "outdoor", 
        'video-games': "entertainment", 
        'base-jumping': "extreme_sports", 
        'skydiving': "extreme_sports", 
        'board-games': "intellectual_hobbies", 
        'polo': "premium_hobbies", 
        'chess': "intellectual_hobbies", 
        'dancing': "fitness_and_sports", 
        'sleeping': "entertainment", 
        'cross-fit': "fitness_and_sports", 
        'basketball': "fitness_and_sports"
    },
    "auto_make" : {
        'Saab': "semi_premium", 
        'Dodge': "mainstream_and_reliable", 
        'Suburu': "mainstream_and_reliable", 
        'Nissan': "mainstream_and_reliable", 
        'Chevrolet': "mainstream_and_reliable", 
        'Ford': "mainstream_and_reliable", 
        'BMW': "premium", 
        'Toyota': "mainstream_and_reliable", 
        'Audi': "premium", 
        'Accura': "premium", 
        'Volkswagen': "semi_premium", 
        'Jeep': "semi_premium", 
        'Mercedes': "premium", 
        'Honda': "mainstream_and_reliable"
    },
}
unknown_value = -1
test_size = 0.2
shuffle = True
random_state = 1234
hyperparameters = {
    "booster" : "gbtree", # NOTE: we want tree-based boosting
    "objective": "binary:logistic", # NOTE : it is a binary classification
    "n_estimators": 1000, 
    "eta": 0.01, # NOTE : rule of thumb n_estimator ~10/eta
    "min_child_weight": 1, # NOTE : if too little it can lead to overfitting
    "seed": 1234, # NOTE : seed for sampling
    "n_jobs": 5, # NOTE : number of cores to use to speed up calculation time
    "base_score": 0.25, # NOTE : % of 1 in the labels -> helps the model to converge faster
    "max_depth": 10, # NOTE : if too high it can lead to overfitting, increase if the nb of features is high
    "subsample": 0.8, # NOTE : % of rows to sample each step -> regularization
    "colsample_bytree": 0.75, # NOTE : % of columns to sample each step -> regularization, to decrease if we have a lot of columns
    "eval_metric": ["auc", "logloss"], # NOTE : we will minimize the loss and observe the auc
}
training_params = {"early_stopping_rounds": 15}

# %% [markdown]
# ## **Input loading**

# %%
import polars as pl 
from pathlib import Path

instances = pl.read_parquet(source=(Path().cwd().parent / "data/02_intermediate/instances.parquet").as_posix()).to_pandas()
labels = pl.read_parquet(source=(Path().cwd().parent / "data/02_intermediate/labels.parquet").as_posix()).to_pandas()

# %% [markdown]
# ## **Execution**

# %%
import functions.ml.preprocessing_functions as preprocessing 
import functions.ml.ml_training_functions as ml_training
import functions.ml.model_explanation_functions as explanation 
import functions.ml.model_prediction_functions as prediction 
import functions.ml.model_evaluation_function as evaluation
import mlflow
import pickle 
import json
from pathlib import Path

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment(experiment_name="technical_test")
with mlflow.start_run(run_name="model_training") as run:
    target_directory = (Path().cwd().parent / "data/03_model_inputs/")
    target_directory.mkdir(parents=True, exist_ok=True)

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Pre processing : Labels...")
    indexed_labels = preprocessing.set_index(data=labels)
    ml_labels = preprocessing.create_response_variable(labels = indexed_labels)
    LOGGER.info("Saving the final table...")
    ml_labels.to_parquet((target_directory / "ml_labels.parquet").as_posix())

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Pre processing : Instances...")
    indexed_instances = preprocessing.set_index(data=instances)
    instances_without_useless_columns = preprocessing.remove_unused_columns(
        data=indexed_instances, 
        columns_to_remove = columns_to_remove
    )
    mlflow.log_param(key = "columns_to_remove", value=columns_to_remove)
    typed_instances = preprocessing.set_features_type(
        data = instances_without_useless_columns, 
        features_type_mapping = features_type_mapping
    )
    mlflow.log_param(key = "features_type_mapping", value=features_type_mapping)
    instances_without_missing_values = preprocessing.impute_missing_values(
        data = typed_instances,
        binary_columns_list = binary_columns_list
    )
    mlflow.log_param(key = "binary_columns_list", value=binary_columns_list)
    columns_order = preprocessing.fit_columns_order(data = instances_without_missing_values)
    with open((target_directory / "columns_order.pkl").as_posix(), "wb") as file:
        pickle.dump(columns_order, file)
    mlflow.log_artifact(
        local_path=(target_directory / "columns_order.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    instances_with_correct_columns_order = preprocessing.transform_columns_order(
        data = instances_without_missing_values,
        columns_order = columns_order
    )
    numerical_data, categorical_data = preprocessing.split_numeric_and_categorical_data(
        data=instances_with_correct_columns_order
    )

    processed_categorical_data = preprocessing.group_high_cardinality_categorical_columns_values(
        data = categorical_data,
        all_categorical_mappings=all_categorical_mappings
    )
    mlflow.log_param(key = "all_categorical_mappings", value=all_categorical_mappings)

    encoder = preprocessing.fit_categorical_encoder(
        data = processed_categorical_data, 
        unknown_value = unknown_value
    )
    with open((target_directory / "encoder.pkl").as_posix(), "wb") as file:
        pickle.dump(encoder, file)
    mlflow.log_artifact(
        local_path=(target_directory / "encoder.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    encoded_categorical_data = preprocessing.transform_categorical_encoder(
        data = processed_categorical_data,
        encoder = encoder 
    )

    ml_features = preprocessing.concatenate_numerical_and_categorical_data(
        numerical_data = numerical_data,
        categorical_data = encoded_categorical_data
    )
    LOGGER.info("Saving the final table...")
    ml_features.to_parquet((target_directory / "ml_features.parquet").as_posix())


    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Training the model...")
    x_train, x_test, y_train, y_test = ml_training.apply_train_test_split(
        x = ml_features, 
        y= ml_labels,
        test_size = test_size,
        shuffle = shuffle, 
        random_state = random_state
    )
    mlflow.log_metric(key="test_size", value=test_size)
    mlflow.log_metric(key="shuffle", value=shuffle)
    mlflow.log_metric(key="random_state", value=random_state)

    xgb_model = ml_training.train_xgb_model(
        x_train = x_train,
        x_test = x_test,
        y_train = y_train,
        y_test = y_test,
        hyperparameters = hyperparameters,
        training_params = training_params,
    )
    mlflow.log_params(hyperparameters)
    mlflow.log_params(training_params)
    with open((target_directory / "xgb_model.pkl").as_posix(), "wb") as file:
        pickle.dump(xgb_model, file)
    mlflow.log_artifact(
        local_path=(target_directory / "xgb_model.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Explaining the model...")
    target_directory = (Path().cwd().parent / "data/04_model_outputs/")
    target_directory.mkdir(parents=True, exist_ok=True)
    shap_values_train = explanation.create_shap_values(
        data = x_train,
        model = xgb_model
    )
    importance_variables_plot = explanation.plot_importance_variables(
        model=xgb_model,
        data=x_train
    )
    importance_variables_plot.savefig(
        (target_directory / "importance_variables_xgb.png").as_posix(),  
        bbox_inches="tight"
    )
    mlflow.log_artifact(
        local_path=(target_directory / "importance_variables_xgb.png").as_posix(), 
        artifact_path="model_explanation"
    )

    dependence_plots = explanation.plot_dependence_plots(
        data=x_train,
        shap_values = shap_values_train,
        encoder=encoder
    )
    for key, value in dependence_plots.items():
        filepath = (target_directory / "dependence_plots")
        filepath.mkdir(parents=True, exist_ok=True)
        value.savefig(
            (filepath / key).as_posix(),  
            bbox_inches="tight"
        )
        mlflow.log_artifact(
            local_path=(filepath / key).as_posix(), 
            artifact_path="model_explanation"
        )

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Evaluating the model...")
    y_probs_test = prediction.predict_probs(data=x_test, model=xgb_model)
    classification_reports = evaluation.create_classification_reports(
        y_true=y_test, y_probs= y_probs_test, thresholds = [0.25,0.3,0.4,0.5,0.6]
    )
    with open((target_directory / "classification_reports.json").as_posix(), "w") as file :
        json.dump(classification_reports, file)
    mlflow.log_artifact(
        local_path=(target_directory / "classification_reports.json").as_posix(), 
        artifact_path="model_evaluation"
    )
# Out:
# 2025-07-12 04:22:18,919 : INFO : -------------------------------------------------
# 2025-07-12 04:22:18,922 : INFO : Pre processing : Labels...
# 2025-07-12 04:22:18,932 : INFO : labels.tp_fraud.value_counts().to_dict() = {0.0: 753, 1.0: 247}
# 2025-07-12 04:22:18,936 : INFO : Saving the final table...
# 2025-07-12 04:22:18,968 : INFO : -------------------------------------------------
# 2025-07-12 04:22:18,970 : INFO : Pre processing : Instances...
# 2025-07-12 04:22:19,362 : INFO : numerical_data.columns = Index(['per_person_limit', 'nb_years_between_incident_and_bind_date',
#        'number_of_vehicles_involved', 'incident_hour_of_the_day', 'age',
#        'capital-loss', 'witnesses', 'auto_year', 'vehicle_claim',
#        'injury_claim', 'policy_deductable', 'capital-gains', 'bodily_injuries',
#        'insured_zip', 'umbrella_limit', 'per_accident_limit', 'property_claim',
#        'months_as_customer', 'policy_annual_premium'],
#       dtype='object')
# 2025-07-12 04:22:19,366 : INFO : categorical_data.columns = Index(['authorities_contacted', 'policy_state', 'property_damage', 'auto_make',
#        'incident_state', 'incident_type', 'collision_type',
#        'police_report_available', 'insured_hobbies', 'insured_education_level',
#        'incident_severity', 'incident_city', 'insured_occupation'],
#       dtype='object')
# 2025-07-12 04:22:19,370 : INFO : Grouping column 'insured_occupation' categories with the following mapping : {'machine-op-inspct': 'workers', 'prof-specialty': 'higher_professions', 'tech-support': 'intermediate', 'sales': 'intermediate', 'exec-managerial': 'higher_professions', 'craft-repair': 'craftmen_traders_entrepreneurs', 'transport-moving': 'craftmen_traders_entrepreneurs', 'priv-house-serv': 'employees', 'other-service': 'employees', 'armed-forces': 'military', 'adm-clerical': 'intermediate', 'protective-serv': 'intermediate', 'handlers-cleaners': 'employees', 'farming-fishing': 'agriculture'}
# 2025-07-12 04:22:19,375 : INFO : New values for column 'insured_occupation' : {'intermediate': 282, 'employees': 196, 'higher_professions': 161, 'craftmen_traders_entrepreneurs': 146, 'workers': 93, 'military': 69, 'agriculture': 53}
# 2025-07-12 04:22:19,377 : INFO : Grouping column 'insured_hobbies' categories with the following mapping : {'reading': 'intellectual_hobbies', 'exercise': 'fitness_and_sports', 'paintball': 'extreme_sports', 'bungie-jumping': 'extreme_sports', 'movies': 'entertainment', 'camping': 'outdoor', 'golf': 'premium_hobbies', 'kayaking': 'outdoor', 'yachting': 'premium_hobbies', 'hiking': 'outdoor', 'video-games': 'entertainment', 'base-jumping': 'extreme_sports', 'skydiving': 'extreme_sports', 'board-games': 'intellectual_hobbies', 'polo': 'premium_hobbies', 'chess': 'intellectual_hobbies', 'dancing': 'fitness_and_sports', 'sleeping': 'entertainment', 'cross-fit': 'fitness_and_sports', 'basketball': 'fitness_and_sports'}
# 2025-07-12 04:22:19,384 : INFO : New values for column 'insured_hobbies' : {'extreme_sports': 211, 'fitness_and_sports': 169, 'outdoor': 161, 'intellectual_hobbies': 158, 'premium_hobbies': 155, 'entertainment': 146}
# 2025-07-12 04:22:19,386 : INFO : Grouping column 'auto_make' categories with the following mapping : {'Saab': 'semi_premium', 'Dodge': 'mainstream_and_reliable', 'Suburu': 'mainstream_and_reliable', 'Nissan': 'mainstream_and_reliable', 'Chevrolet': 'mainstream_and_reliable', 'Ford': 'mainstream_and_reliable', 'BMW': 'premium', 'Toyota': 'mainstream_and_reliable', 'Audi': 'premium', 'Accura': 'premium', 'Volkswagen': 'semi_premium', 'Jeep': 'semi_premium', 'Mercedes': 'premium', 'Honda': 'mainstream_and_reliable'}
# 2025-07-12 04:22:19,390 : INFO : New values for column 'auto_make' : {'mainstream_and_reliable': 511, 'premium': 274, 'semi_premium': 215}
# 2025-07-12 04:22:19,513 : INFO : Saving the final table...
# 2025-07-12 04:22:19,540 : INFO : -------------------------------------------------
# 2025-07-12 04:22:19,542 : INFO : Training the model...
# [0]	validation_0-auc:0.57973	validation_0-logloss:0.62242
# [1]	validation_0-auc:0.52919	validation_0-logloss:0.62240
# [2]	validation_0-auc:0.69159	validation_0-logloss:0.61978
# [3]	validation_0-auc:0.77745	validation_0-logloss:0.61686
# [4]	validation_0-auc:0.76058	validation_0-logloss:0.61703
# [5]	validation_0-auc:0.78134	validation_0-logloss:0.61476
# [6]	validation_0-auc:0.79868	validation_0-logloss:0.61210
# [7]	validation_0-auc:0.81142	validation_0-logloss:0.60970
# [8]	validation_0-auc:0.81201	validation_0-logloss:0.60759
# [9]	validation_0-auc:0.81720	validation_0-logloss:0.60499
# [10]	validation_0-auc:0.82356	validation_0-logloss:0.60269
# [11]	validation_0-auc:0.82345	validation_0-logloss:0.60277
# [12]	validation_0-auc:0.81779	validation_0-logloss:0.60244
# [13]	validation_0-auc:0.81324	validation_0-logloss:0.60024
# [14]	validation_0-auc:0.81708	validation_0-logloss:0.59787
# [15]	validation_0-auc:0.82286	validation_0-logloss:0.59538
# [16]	validation_0-auc:0.81566	validation_0-logloss:0.59539
# [17]	validation_0-auc:0.81436	validation_0-logloss:0.59549
# [18]	validation_0-auc:0.81436	validation_0-logloss:0.59535
# [19]	validation_0-auc:0.81696	validation_0-logloss:0.59277
# [20]	validation_0-auc:0.81979	validation_0-logloss:0.59072
# [21]	validation_0-auc:0.82639	validation_0-logloss:0.59040
# [22]	validation_0-auc:0.83123	validation_0-logloss:0.58805
# [23]	validation_0-auc:0.82981	validation_0-logloss:0.58808
# [24]	validation_0-auc:0.83430	validation_0-logloss:0.58733
# [25]	validation_0-auc:0.83854	validation_0-logloss:0.58534
# [26]	validation_0-auc:0.83524	validation_0-logloss:0.58510
# [27]	validation_0-auc:0.82864	validation_0-logloss:0.58516
# [28]	validation_0-auc:0.83135	validation_0-logloss:0.58286
# [29]	validation_0-auc:0.83524	validation_0-logloss:0.58079
# [30]	validation_0-auc:0.83359	validation_0-logloss:0.58076
# [31]	validation_0-auc:0.83265	validation_0-logloss:0.57861
# [32]	validation_0-auc:0.83123	validation_0-logloss:0.57871
# [33]	validation_0-auc:0.83040	validation_0-logloss:0.57713
# [34]	validation_0-auc:0.83300	validation_0-logloss:0.57515
# [35]	validation_0-auc:0.83489	validation_0-logloss:0.57328
# [36]	validation_0-auc:0.83772	validation_0-logloss:0.57104
# [37]	validation_0-auc:0.83760	validation_0-logloss:0.56914
# [38]	validation_0-auc:0.83772	validation_0-logloss:0.56747
# [39]	validation_0-auc:0.83607	validation_0-logloss:0.56763
# [40]	validation_0-auc:0.83795	validation_0-logloss:0.56565
# [41]	validation_0-auc:0.83949	validation_0-logloss:0.56422
# [42]	validation_0-auc:0.84184	validation_0-logloss:0.56257
# [43]	validation_0-auc:0.84055	validation_0-logloss:0.56239
# [44]	validation_0-auc:0.83937	validation_0-logloss:0.56246
# [45]	validation_0-auc:0.83772	validation_0-logloss:0.56139
# [46]	validation_0-auc:0.83890	validation_0-logloss:0.55994
# [47]	validation_0-auc:0.83996	validation_0-logloss:0.55836
# [48]	validation_0-auc:0.84125	validation_0-logloss:0.55649
# [49]	validation_0-auc:0.83913	validation_0-logloss:0.55532
# [50]	validation_0-auc:0.84090	validation_0-logloss:0.55345
# [51]	validation_0-auc:0.84208	validation_0-logloss:0.55182
# [52]	validation_0-auc:0.84161	validation_0-logloss:0.55046
# [53]	validation_0-auc:0.84409	validation_0-logloss:0.54855
# [54]	validation_0-auc:0.84585	validation_0-logloss:0.54700
# [55]	validation_0-auc:0.84762	validation_0-logloss:0.54527
# [56]	validation_0-auc:0.85022	validation_0-logloss:0.54314
# [57]	validation_0-auc:0.85010	validation_0-logloss:0.54168
# [58]	validation_0-auc:0.84963	validation_0-logloss:0.54037
# [59]	validation_0-auc:0.84963	validation_0-logloss:0.53938
# [60]	validation_0-auc:0.85022	validation_0-logloss:0.53794
# [61]	validation_0-auc:0.84986	validation_0-logloss:0.53639
# [62]	validation_0-auc:0.85045	validation_0-logloss:0.53463
# [63]	validation_0-auc:0.85175	validation_0-logloss:0.53463
# [64]	validation_0-auc:0.85069	validation_0-logloss:0.53352
# [65]	validation_0-auc:0.85187	validation_0-logloss:0.53230
# [66]	validation_0-auc:0.85081	validation_0-logloss:0.53117
# [67]	validation_0-auc:0.85022	validation_0-logloss:0.53041
# [68]	validation_0-auc:0.84916	validation_0-logloss:0.52955
# [69]	validation_0-auc:0.84927	validation_0-logloss:0.52989
# [70]	validation_0-auc:0.84786	validation_0-logloss:0.53015
# [71]	validation_0-auc:0.84892	validation_0-logloss:0.52879
# [72]	validation_0-auc:0.84821	validation_0-logloss:0.52773
# [73]	validation_0-auc:0.84868	validation_0-logloss:0.52689
# [74]	validation_0-auc:0.84751	validation_0-logloss:0.52617
# [75]	validation_0-auc:0.84762	validation_0-logloss:0.52555
# [76]	validation_0-auc:0.84786	validation_0-logloss:0.52427
# [77]	validation_0-auc:0.84739	validation_0-logloss:0.52298
# [78]	validation_0-auc:0.84715	validation_0-logloss:0.52240
# [79]	validation_0-auc:0.84751	validation_0-logloss:0.52136
# [80]	validation_0-auc:0.84904	validation_0-logloss:0.52019
# [81]	validation_0-auc:0.84703	validation_0-logloss:0.51988
# [82]	validation_0-auc:0.84715	validation_0-logloss:0.51886
# [83]	validation_0-auc:0.84656	validation_0-logloss:0.51830
# [84]	validation_0-auc:0.84609	validation_0-logloss:0.51737
# [85]	validation_0-auc:0.84585	validation_0-logloss:0.51659
# [86]	validation_0-auc:0.84715	validation_0-logloss:0.51627
# [87]	validation_0-auc:0.84609	validation_0-logloss:0.51555
# [88]	validation_0-auc:0.84644	validation_0-logloss:0.51425
# [89]	validation_0-auc:0.84550	validation_0-logloss:0.51452
# [90]	validation_0-auc:0.84574	validation_0-logloss:0.51390
# [91]	validation_0-auc:0.84692	validation_0-logloss:0.51311
# [92]	validation_0-auc:0.84739	validation_0-logloss:0.51195
# [93]	validation_0-auc:0.84751	validation_0-logloss:0.51136
# [94]	validation_0-auc:0.84762	validation_0-logloss:0.51110
# [95]	validation_0-auc:0.84762	validation_0-logloss:0.51155
# [96]	validation_0-auc:0.84751	validation_0-logloss:0.51064
# [97]	validation_0-auc:0.84892	validation_0-logloss:0.50971
# [98]	validation_0-auc:0.84939	validation_0-logloss:0.50955
# [99]	validation_0-auc:0.85034	validation_0-logloss:0.50863
# [100]	validation_0-auc:0.84939	validation_0-logloss:0.50867
# [101]	validation_0-auc:0.84692	validation_0-logloss:0.50816
# [102]	validation_0-auc:0.84739	validation_0-logloss:0.50754
# [103]	validation_0-auc:0.84739	validation_0-logloss:0.50623
# [104]	validation_0-auc:0.84833	validation_0-logloss:0.50515
# [105]	validation_0-auc:0.84986	validation_0-logloss:0.50427
# [106]	validation_0-auc:0.84998	validation_0-logloss:0.50349
# [107]	validation_0-auc:0.84880	validation_0-logloss:0.50286
# [108]	validation_0-auc:0.85010	validation_0-logloss:0.50175
# [109]	validation_0-auc:0.85116	validation_0-logloss:0.50104
# [110]	validation_0-auc:0.85152	validation_0-logloss:0.50011
# [111]	validation_0-auc:0.85163	validation_0-logloss:0.49936
# [112]	validation_0-auc:0.85163	validation_0-logloss:0.49858
# [113]	validation_0-auc:0.85199	validation_0-logloss:0.49782
# [114]	validation_0-auc:0.85340	validation_0-logloss:0.49664
# [115]	validation_0-auc:0.85376	validation_0-logloss:0.49575
# [116]	validation_0-auc:0.85411	validation_0-logloss:0.49537
# [117]	validation_0-auc:0.85458	validation_0-logloss:0.49475
# [118]	validation_0-auc:0.85387	validation_0-logloss:0.49482
# [119]	validation_0-auc:0.85435	validation_0-logloss:0.49456
# [120]	validation_0-auc:0.85458	validation_0-logloss:0.49409
# [121]	validation_0-auc:0.85446	validation_0-logloss:0.49345
# [122]	validation_0-auc:0.85470	validation_0-logloss:0.49362
# [123]	validation_0-auc:0.85446	validation_0-logloss:0.49302
# [124]	validation_0-auc:0.85482	validation_0-logloss:0.49239
# [125]	validation_0-auc:0.85517	validation_0-logloss:0.49188
# [126]	validation_0-auc:0.85446	validation_0-logloss:0.49144
# [127]	validation_0-auc:0.85482	validation_0-logloss:0.49068
# [128]	validation_0-auc:0.85470	validation_0-logloss:0.49009
# [129]	validation_0-auc:0.85482	validation_0-logloss:0.48933
# [130]	validation_0-auc:0.85600	validation_0-logloss:0.48911
# [131]	validation_0-auc:0.85576	validation_0-logloss:0.48845
# [132]	validation_0-auc:0.85623	validation_0-logloss:0.48761
# [133]	validation_0-auc:0.85553	validation_0-logloss:0.48715
# [134]	validation_0-auc:0.85647	validation_0-logloss:0.48645
# [135]	validation_0-auc:0.85670	validation_0-logloss:0.48590
# [136]	validation_0-auc:0.85647	validation_0-logloss:0.48523
# [137]	validation_0-auc:0.85623	validation_0-logloss:0.48492
# [138]	validation_0-auc:0.85659	validation_0-logloss:0.48461
# [139]	validation_0-auc:0.85706	validation_0-logloss:0.48473
# [140]	validation_0-auc:0.85753	validation_0-logloss:0.48418
# [141]	validation_0-auc:0.85706	validation_0-logloss:0.48381
# [142]	validation_0-auc:0.85694	validation_0-logloss:0.48338
# [143]	validation_0-auc:0.85623	validation_0-logloss:0.48339
# [144]	validation_0-auc:0.85494	validation_0-logloss:0.48377
# [145]	validation_0-auc:0.85505	validation_0-logloss:0.48377
# [146]	validation_0-auc:0.85387	validation_0-logloss:0.48323
# [147]	validation_0-auc:0.85446	validation_0-logloss:0.48268
# [148]	validation_0-auc:0.85458	validation_0-logloss:0.48236
# [149]	validation_0-auc:0.85470	validation_0-logloss:0.48156
# [150]	validation_0-auc:0.85517	validation_0-logloss:0.48097
# [151]	validation_0-auc:0.85482	validation_0-logloss:0.48112
# [152]	validation_0-auc:0.85541	validation_0-logloss:0.48075
# [153]	validation_0-auc:0.85541	validation_0-logloss:0.48039
# [154]	validation_0-auc:0.85623	validation_0-logloss:0.48000
# [155]	validation_0-auc:0.85694	validation_0-logloss:0.47975
# [156]	validation_0-auc:0.85682	validation_0-logloss:0.47938
# [157]	validation_0-auc:0.85635	validation_0-logloss:0.47936
# [158]	validation_0-auc:0.85741	validation_0-logloss:0.47912
# [159]	validation_0-auc:0.85788	validation_0-logloss:0.47834
# [160]	validation_0-auc:0.85800	validation_0-logloss:0.47817
# [161]	validation_0-auc:0.85824	validation_0-logloss:0.47821
# [162]	validation_0-auc:0.85765	validation_0-logloss:0.47804
# [163]	validation_0-auc:0.85777	validation_0-logloss:0.47760
# [164]	validation_0-auc:0.85812	validation_0-logloss:0.47691
# [165]	validation_0-auc:0.85753	validation_0-logloss:0.47696
# [166]	validation_0-auc:0.85741	validation_0-logloss:0.47659
# [167]	validation_0-auc:0.85670	validation_0-logloss:0.47642
# [168]	validation_0-auc:0.85623	validation_0-logloss:0.47609
# [169]	validation_0-auc:0.85623	validation_0-logloss:0.47579
# [170]	validation_0-auc:0.85659	validation_0-logloss:0.47562
# [171]	validation_0-auc:0.85670	validation_0-logloss:0.47521
# [172]	validation_0-auc:0.85623	validation_0-logloss:0.47490
# [173]	validation_0-auc:0.85612	validation_0-logloss:0.47432
# [174]	validation_0-auc:0.85623	validation_0-logloss:0.47398
# [175]	validation_0-auc:0.85612	validation_0-logloss:0.47395
# [176]	validation_0-auc:0.85670	validation_0-logloss:0.47370
# [177]	validation_0-auc:0.85600	validation_0-logloss:0.47370
# [178]	validation_0-auc:0.85612	validation_0-logloss:0.47322
# [179]	validation_0-auc:0.85564	validation_0-logloss:0.47251
# [180]	validation_0-auc:0.85647	validation_0-logloss:0.47229
# [181]	validation_0-auc:0.85694	validation_0-logloss:0.47210
# [182]	validation_0-auc:0.85670	validation_0-logloss:0.47242
# [183]	validation_0-auc:0.85788	validation_0-logloss:0.47168
# [184]	validation_0-auc:0.85729	validation_0-logloss:0.47168
# [185]	validation_0-auc:0.85682	validation_0-logloss:0.47140
# [186]	validation_0-auc:0.85753	validation_0-logloss:0.47150
# [187]	validation_0-auc:0.85718	validation_0-logloss:0.47111
# [188]	validation_0-auc:0.85718	validation_0-logloss:0.47057
# [189]	validation_0-auc:0.85718	validation_0-logloss:0.47017
# [190]	validation_0-auc:0.85682	validation_0-logloss:0.47028
# [191]	validation_0-auc:0.85718	validation_0-logloss:0.46983
# [192]	validation_0-auc:0.85659	validation_0-logloss:0.46962
# [193]	validation_0-auc:0.85729	validation_0-logloss:0.46910
# [194]	validation_0-auc:0.85659	validation_0-logloss:0.46948
# [195]	validation_0-auc:0.85553	validation_0-logloss:0.46948
# [196]	validation_0-auc:0.85564	validation_0-logloss:0.46960
# [197]	validation_0-auc:0.85635	validation_0-logloss:0.46965
# [198]	validation_0-auc:0.85741	validation_0-logloss:0.46941
# [199]	validation_0-auc:0.85718	validation_0-logloss:0.46909
# [200]	validation_0-auc:0.85718	validation_0-logloss:0.46891
# [201]	validation_0-auc:0.85694	validation_0-logloss:0.46867
# [202]	validation_0-auc:0.85670	validation_0-logloss:0.46843
# [203]	validation_0-auc:0.85659	validation_0-logloss:0.46837
# [204]	validation_0-auc:0.85706	validation_0-logloss:0.46823
# [205]	validation_0-auc:0.85741	validation_0-logloss:0.46829
# [206]	validation_0-auc:0.85800	validation_0-logloss:0.46836
# [207]	validation_0-auc:0.85788	validation_0-logloss:0.46840
# [208]	validation_0-auc:0.85777	validation_0-logloss:0.46833
# [209]	validation_0-auc:0.85800	validation_0-logloss:0.46810
# [210]	validation_0-auc:0.85788	validation_0-logloss:0.46788
# [211]	validation_0-auc:0.85694	validation_0-logloss:0.46744
# [212]	validation_0-auc:0.85777	validation_0-logloss:0.46693
# [213]	validation_0-auc:0.85788	validation_0-logloss:0.46640
# [214]	validation_0-auc:0.85954	validation_0-logloss:0.46637
# [215]	validation_0-auc:0.85918	validation_0-logloss:0.46579
# [216]	validation_0-auc:0.85906	validation_0-logloss:0.46575
# [217]	validation_0-auc:0.85800	validation_0-logloss:0.46588
# [218]	validation_0-auc:0.85800	validation_0-logloss:0.46561
# [219]	validation_0-auc:0.85718	validation_0-logloss:0.46549
# [220]	validation_0-auc:0.85788	validation_0-logloss:0.46518
# [221]	validation_0-auc:0.85812	validation_0-logloss:0.46539
# [222]	validation_0-auc:0.85777	validation_0-logloss:0.46557
# [223]	validation_0-auc:0.85800	validation_0-logloss:0.46541
# [224]	validation_0-auc:0.85812	validation_0-logloss:0.46537
# [225]	validation_0-auc:0.85777	validation_0-logloss:0.46509
# [226]	validation_0-auc:0.85847	validation_0-logloss:0.46481
# [227]	validation_0-auc:0.85847	validation_0-logloss:0.46458
# [228]	validation_0-auc:0.85824	validation_0-logloss:0.46468
# [229]	validation_0-auc:0.85836	validation_0-logloss:0.46444
# [230]	validation_0-auc:0.85812	validation_0-logloss:0.46439
# [231]	validation_0-auc:0.85836	validation_0-logloss:0.46417
# [232]	validation_0-auc:0.85836	validation_0-logloss:0.46410
# [233]	validation_0-auc:0.85788	validation_0-logloss:0.46391
# [234]	validation_0-auc:0.85788	validation_0-logloss:0.46389
# [235]	validation_0-auc:0.85812	validation_0-logloss:0.46404
# [236]	validation_0-auc:0.85895	validation_0-logloss:0.46420
# [237]	validation_0-auc:0.85777	validation_0-logloss:0.46431
# [238]	validation_0-auc:0.85812	validation_0-logloss:0.46460
# [239]	validation_0-auc:0.85777	validation_0-logloss:0.46430
# [240]	validation_0-auc:0.85800	validation_0-logloss:0.46418
# [241]	validation_0-auc:0.85777	validation_0-logloss:0.46387
# [242]	validation_0-auc:0.85777	validation_0-logloss:0.46377
# [243]	validation_0-auc:0.85753	validation_0-logloss:0.46407
# [244]	validation_0-auc:0.85659	validation_0-logloss:0.46411
# [245]	validation_0-auc:0.85741	validation_0-logloss:0.46414
# [246]	validation_0-auc:0.85694	validation_0-logloss:0.46407
# [247]	validation_0-auc:0.85682	validation_0-logloss:0.46396
# [248]	validation_0-auc:0.85682	validation_0-logloss:0.46395
# [249]	validation_0-auc:0.85718	validation_0-logloss:0.46392
# [250]	validation_0-auc:0.85765	validation_0-logloss:0.46340
# [251]	validation_0-auc:0.85753	validation_0-logloss:0.46332
# [252]	validation_0-auc:0.85741	validation_0-logloss:0.46317
# [253]	validation_0-auc:0.85800	validation_0-logloss:0.46293
# [254]	validation_0-auc:0.85800	validation_0-logloss:0.46319
# [255]	validation_0-auc:0.85788	validation_0-logloss:0.46316
# [256]	validation_0-auc:0.85847	validation_0-logloss:0.46292
# [257]	validation_0-auc:0.85847	validation_0-logloss:0.46277
# [258]	validation_0-auc:0.85788	validation_0-logloss:0.46265
# [259]	validation_0-auc:0.85800	validation_0-logloss:0.46245
# [260]	validation_0-auc:0.85812	validation_0-logloss:0.46213
# [261]	validation_0-auc:0.85729	validation_0-logloss:0.46217
# [262]	validation_0-auc:0.85765	validation_0-logloss:0.46198
# [263]	validation_0-auc:0.85729	validation_0-logloss:0.46200
# [264]	validation_0-auc:0.85800	validation_0-logloss:0.46191
# [265]	validation_0-auc:0.85765	validation_0-logloss:0.46176
# [266]	validation_0-auc:0.85753	validation_0-logloss:0.46191
# [267]	validation_0-auc:0.85718	validation_0-logloss:0.46186
# [268]	validation_0-auc:0.85729	validation_0-logloss:0.46205
# [269]	validation_0-auc:0.85729	validation_0-logloss:0.46218
# [270]	validation_0-auc:0.85647	validation_0-logloss:0.46210
# [271]	validation_0-auc:0.85588	validation_0-logloss:0.46189
# [272]	validation_0-auc:0.85612	validation_0-logloss:0.46186
# [273]	validation_0-auc:0.85635	validation_0-logloss:0.46156
# [274]	validation_0-auc:0.85659	validation_0-logloss:0.46163
# [275]	validation_0-auc:0.85635	validation_0-logloss:0.46139
# [276]	validation_0-auc:0.85612	validation_0-logloss:0.46113
# [277]	validation_0-auc:0.85718	validation_0-logloss:0.46105
# [278]	validation_0-auc:0.85800	validation_0-logloss:0.46095
# [279]	validation_0-auc:0.85670	validation_0-logloss:0.46108
# [280]	validation_0-auc:0.85694	validation_0-logloss:0.46130
# [281]	validation_0-auc:0.85647	validation_0-logloss:0.46135
# [282]	validation_0-auc:0.85659	validation_0-logloss:0.46132
# [283]	validation_0-auc:0.85635	validation_0-logloss:0.46110
# [284]	validation_0-auc:0.85706	validation_0-logloss:0.46086
# [285]	validation_0-auc:0.85718	validation_0-logloss:0.46075
# [286]	validation_0-auc:0.85788	validation_0-logloss:0.46044
# [287]	validation_0-auc:0.85718	validation_0-logloss:0.46008
# [288]	validation_0-auc:0.85682	validation_0-logloss:0.46021
# [289]	validation_0-auc:0.85682	validation_0-logloss:0.46010
# [290]	validation_0-auc:0.85682	validation_0-logloss:0.45979
# [291]	validation_0-auc:0.85670	validation_0-logloss:0.45953
# [292]	validation_0-auc:0.85600	validation_0-logloss:0.45960
# [293]	validation_0-auc:0.85647	validation_0-logloss:0.45966
# [294]	validation_0-auc:0.85635	validation_0-logloss:0.45974
# [295]	validation_0-auc:0.85635	validation_0-logloss:0.45968
# [296]	validation_0-auc:0.85682	validation_0-logloss:0.45952
# [297]	validation_0-auc:0.85694	validation_0-logloss:0.45938
# [298]	validation_0-auc:0.85718	validation_0-logloss:0.45892
# [299]	validation_0-auc:0.85777	validation_0-logloss:0.45861
# [300]	validation_0-auc:0.85788	validation_0-logloss:0.45835
# [301]	validation_0-auc:0.85777	validation_0-logloss:0.45829
# [302]	validation_0-auc:0.85753	validation_0-logloss:0.45826
# [303]	validation_0-auc:0.85753	validation_0-logloss:0.45800
# [304]	validation_0-auc:0.85729	validation_0-logloss:0.45787
# [305]	validation_0-auc:0.85682	validation_0-logloss:0.45818
# [306]	validation_0-auc:0.85659	validation_0-logloss:0.45821
# [307]	validation_0-auc:0.85741	validation_0-logloss:0.45834
# [308]	validation_0-auc:0.85706	validation_0-logloss:0.45818
# [309]	validation_0-auc:0.85777	validation_0-logloss:0.45814
# [310]	validation_0-auc:0.85753	validation_0-logloss:0.45804
# [311]	validation_0-auc:0.85718	validation_0-logloss:0.45798
# [312]	validation_0-auc:0.85718	validation_0-logloss:0.45802
# [313]	validation_0-auc:0.85753	validation_0-logloss:0.45798
# [314]	validation_0-auc:0.85706	validation_0-logloss:0.45798
# [315]	validation_0-auc:0.85729	validation_0-logloss:0.45804
# [316]	validation_0-auc:0.85753	validation_0-logloss:0.45810
# [317]	validation_0-auc:0.85777	validation_0-logloss:0.45805
# [318]	validation_0-auc:0.85753	validation_0-logloss:0.45788
# [319]	validation_0-auc:0.85729	validation_0-logloss:0.45782
# [320]	validation_0-auc:0.85718	validation_0-logloss:0.45768
# [321]	validation_0-auc:0.85718	validation_0-logloss:0.45765
# [322]	validation_0-auc:0.85788	validation_0-logloss:0.45770
# [323]	validation_0-auc:0.85788	validation_0-logloss:0.45769
# [324]	validation_0-auc:0.85753	validation_0-logloss:0.45787
# [325]	validation_0-auc:0.85753	validation_0-logloss:0.45763
# [326]	validation_0-auc:0.85777	validation_0-logloss:0.45752
# [327]	validation_0-auc:0.85718	validation_0-logloss:0.45764
# [328]	validation_0-auc:0.85777	validation_0-logloss:0.45735
# [329]	validation_0-auc:0.85765	validation_0-logloss:0.45736
# [330]	validation_0-auc:0.85777	validation_0-logloss:0.45742
# [331]	validation_0-auc:0.85765	validation_0-logloss:0.45714
# [332]	validation_0-auc:0.85765	validation_0-logloss:0.45740
# [333]	validation_0-auc:0.85824	validation_0-logloss:0.45743
# [334]	validation_0-auc:0.85836	validation_0-logloss:0.45713
# [335]	validation_0-auc:0.85847	validation_0-logloss:0.45699
# [336]	validation_0-auc:0.85788	validation_0-logloss:0.45690
# [337]	validation_0-auc:0.85847	validation_0-logloss:0.45698
# [338]	validation_0-auc:0.85847	validation_0-logloss:0.45685
# [339]	validation_0-auc:0.85812	validation_0-logloss:0.45665
# [340]	validation_0-auc:0.85836	validation_0-logloss:0.45660
# [341]	validation_0-auc:0.85847	validation_0-logloss:0.45654
# [342]	validation_0-auc:0.85906	validation_0-logloss:0.45628
# [343]	validation_0-auc:0.85906	validation_0-logloss:0.45630
# [344]	validation_0-auc:0.85836	validation_0-logloss:0.45647
# [345]	validation_0-auc:0.85895	validation_0-logloss:0.45651
# [346]	validation_0-auc:0.85906	validation_0-logloss:0.45654
# [347]	validation_0-auc:0.85871	validation_0-logloss:0.45661
# [348]	validation_0-auc:0.85883	validation_0-logloss:0.45650
# [349]	validation_0-auc:0.85883	validation_0-logloss:0.45632
# [350]	validation_0-auc:0.85906	validation_0-logloss:0.45603
# [351]	validation_0-auc:0.85930	validation_0-logloss:0.45584
# [352]	validation_0-auc:0.85883	validation_0-logloss:0.45588
# [353]	validation_0-auc:0.85918	validation_0-logloss:0.45562
# [354]	validation_0-auc:0.85965	validation_0-logloss:0.45569
# [355]	validation_0-auc:0.85965	validation_0-logloss:0.45582
# [356]	validation_0-auc:0.85977	validation_0-logloss:0.45606
# [357]	validation_0-auc:0.85918	validation_0-logloss:0.45614
# [358]	validation_0-auc:0.85954	validation_0-logloss:0.45622
# [359]	validation_0-auc:0.86013	validation_0-logloss:0.45592
# [360]	validation_0-auc:0.86001	validation_0-logloss:0.45580
# [361]	validation_0-auc:0.85977	validation_0-logloss:0.45591
# [362]	validation_0-auc:0.85930	validation_0-logloss:0.45579
# [363]	validation_0-auc:0.85859	validation_0-logloss:0.45584
# [364]	validation_0-auc:0.85895	validation_0-logloss:0.45583
# [365]	validation_0-auc:0.85871	validation_0-logloss:0.45597
# [366]	validation_0-auc:0.85930	validation_0-logloss:0.45597
# [367]	validation_0-auc:0.85906	validation_0-logloss:0.45589
# [368]	validation_0-auc:0.85930	validation_0-logloss:0.45572
# 2025-07-12 04:22:42,848 : INFO : -------------------------------------------------
# 2025-07-12 04:22:42,851 : INFO : Explaining the model...
# 2025-07-12 04:22:50,727 : INFO : -------------------------------------------------
# 2025-07-12 04:22:50,730 : INFO : Evaluating the model...
# 🏃 View run model_training at: http://localhost:5000/#/experiments/222123412902236260/runs/15435b26623448a181f1865c04439a53
# 🧪 View experiment at: http://localhost:5000/#/experiments/222123412902236260

# %% [markdown]
# # **Conclusions & more**
#
# - the idea was to predict the probability of fraud and then choose a threshold to determine wether a predicted individual is a fraud or not
# - the problem was a binary classification with imbalanced classes so it is better to do so instead of predicting the class directly (most of the time the threshold is fixed at 50% so with an imbalanced classification the true positives will likely stay at 0)
# - what metrics did I choose during model training ? : minimizing the log loss
#     - for an imbalanced classification, it is better to predict probabilities and then choose a threshold (every probs >= threshold will be considered as a fraud)
#     - the log loss is a "distance" between the labels and the predicted probabilities, so minimizing it will help calibrate the model
# - what metrics did I choose to evaluate the model ? :
#     - precision
#     - recall
#     - the confusion matrix
# - these are the prefered metrics in this case because :
#     - for fraud detection what matters the most is the nb of fraud detected and the amount of cases the model predicts as a high risk of fraud
#     - for an imbalanced classification problem looking at the accuracy is not advised (if i only have 5% of 1 in my labels, by predicting everyone to 0 i will have a 95% accuracy)
# - what are the results ? :
#
# ```json
# {
#     "classification_report_threshold_25%": {
#         "precision": 0.6774193548387096,
#         "recal": 0.6885245901639344,
#         "true_positives": 42.0,
#         "false_positives": 20.0,
#         "true_negatives": 119.0,
#         "false_negatives": 19.0
#     },
#     "classification_report_threshold_30%": {
#         "precision": 0.7272727272727273,
#         "recal": 0.6557377049180327,
#         "true_positives": 40.0,
#         "false_positives": 15.0,
#         "true_negatives": 124.0,
#         "false_negatives": 21.0
#     },
#     "classification_report_threshold_40%": {
#         "precision": 0.7391304347826086,
#         "recal": 0.5573770491803278,
#         "true_positives": 34.0,
#         "false_positives": 12.0,
#         "true_negatives": 127.0,
#         "false_negatives": 27.0
#     },
#     "classification_report_threshold_50%": {
#         "precision": 0.8484848484848485,
#         "recal": 0.45901639344262296,
#         "true_positives": 28.0,
#         "false_positives": 5.0,
#         "true_negatives": 134.0,
#         "false_negatives": 33.0
#     },
#     "classification_report_threshold_60%": {
#         "precision": 0.8666666666666667,
#         "recal": 0.21311475409836064,
#         "true_positives": 13.0,
#         "false_positives": 2.0,
#         "true_negatives": 137.0,
#         "false_negatives": 48.0
#     }
# }
# ```
# - the goal is to find a balance between precision and recall, we want to detect enough frauds but without making too much controls, fraud investigations are usually quite costly for insurance companies.
# - the great compromise in our case could be choosing a threshold around 25~30%
