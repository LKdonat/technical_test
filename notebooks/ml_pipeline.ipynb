# %% [markdown]
# # **ML pipeline**
#
# - This notebook contains the pre-processing and the model training phase
# - During the training the model evaluation & explanation results will be logged in local mlflow runs.
# - Why grouping the 2 steps ?
#     - This phase contains all the 'fit' steps : we will fit the encoder and the model so that it can be used later on during inference
# - Choice of the model : why choosing XGBoost ?
#     - `Time` : we don't dispose of a lot of time to benchmark multiple algorithms so we need to make a choice
#     - `Performance` : XGBoost has proven to be the winning solution algorithm in numerous hackathons (kaggle,...)
#     - `Calibration` : easy to calibrate and allows the user to easily perform regularization and prevent overfitting
#     - `Scalability` : fast and consistent execution time even with large datasets
#     - `Explainability` : TreeSHAP algorithm is able to calculate very accurate SHAP values for tree-based models
#     - `Conveniency` : The tree-base nature of the model allows us to skip multiple pre-processing steps such as normalization, standardization & extreme values processing
# - "No Free Lunch" :
#     - There is no ML model that is indisputably better than others, for a binary classification problem with structured data the model performances will be considerably enhanced by relevant and quality features.
#     - Hyperparameters fine-tuning is the cherry on the cake.

# %%
import sys
from pathlib import Path
import logging 
import warnings
warnings.filterwarnings('ignore')

LOGGER = logging.getLogger(__name__)
sys.path.append(str(Path("../src").resolve())) 

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# ## **Parameters**

# %%
columns_to_remove = ["policy_bind_date", "incident_date", "total_claim_amount"]
features_type_mapping = {
    'policy_state': "str", 
    'insured_education_level': "str", 
    'insured_occupation': "str",
    'insured_hobbies': "str", 
    'incident_type': "str", 
    'collision_type': "str",
    'incident_severity': "str", 
    'authorities_contacted': "str", 
    'incident_state': "str",
    'incident_city': "str", 
    'property_damage': "str", 
    'police_report_available': "str",
    'auto_make': "str"
}
binary_columns_list = ["property_damage", "police_report_available"]
unknown_value = -1
test_size = 0.2
shuffle = True
random_state = 1234
hyperparameters = {
    "booster" : "gbtree", # NOTE: we want tree-based boosting
    "objective": "binary:logistic", # NOTE : it is a binary classification
    "n_estimators": 1000, 
    "eta": 0.01, # NOTE : rule of thumb n_estimator ~10/eta
    "min_child_weight": 1, # NOTE : if too little it can lead to overfitting
    "seed": 1234, # NOTE : seed for sampling
    "n_jobs": 5, # NOTE : number of cores to use to speed up calculation time
    "base_score": 0.25, # NOTE : % of 1 in the labels -> helps the model to converge faster
    "max_depth": 8, # NOTE : if too high it can lead to overfitting, increase if the nb of features is high
    "subsample": 0.8, # NOTE : % of rows to sample each step -> regularization
    "colsample_bytree": 0.75, # NOTE : % of columns to sample each step -> regularization, to decrease if we have a lot of columns
    "eval_metric": ["auc", "logloss"], # NOTE : we will minimize the loss and observe the auc during training
}
training_params = {"early_stopping_rounds": 15} # NOTE : the number of rounds after which the training should stop if there is no improvement on the training metrics

# %% [markdown]
# ## **Input loading**

# %%
import polars as pl 
from pathlib import Path

instances = pl.read_parquet(source=(Path().cwd().parent / "data/02_intermediate/instances.parquet").as_posix()).to_pandas()
labels = pl.read_parquet(source=(Path().cwd().parent / "data/02_intermediate/labels.parquet").as_posix()).to_pandas()

# %% [markdown]
# ## **Execution**

# %%
import functions.ml.preprocessing_functions as preprocessing 
import functions.ml.ml_training_functions as ml_training
import functions.ml.model_explanation_functions as explanation 
import functions.ml.model_prediction_functions as prediction 
import functions.ml.model_evaluation_function as evaluation
import mlflow
import pickle 
import json
from pathlib import Path

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment(experiment_name="technical_test")
with mlflow.start_run(run_name="model_training") as run:
    target_directory = (Path().cwd().parent / "data/03_model_inputs/")
    target_directory.mkdir(parents=True, exist_ok=True)

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Pre processing : Labels...")
    indexed_labels = preprocessing.set_index(data=labels)
    ml_labels = preprocessing.create_response_variable(labels = indexed_labels)
    LOGGER.info("Saving the final table...")
    ml_labels.to_parquet((target_directory / "ml_labels.parquet").as_posix())

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Pre processing : Instances...")
    indexed_instances = preprocessing.set_index(data=instances)
    instances_without_useless_columns = preprocessing.remove_unused_columns(
        data=indexed_instances, 
        columns_to_remove = columns_to_remove
    )
    mlflow.log_param(key = "columns_to_remove", value=columns_to_remove)
    typed_instances = preprocessing.set_features_type(
        data = instances_without_useless_columns, 
        features_type_mapping = features_type_mapping
    )
    mlflow.log_param(key = "features_type_mapping", value=features_type_mapping)
    instances_without_missing_values = preprocessing.impute_missing_values(
        data = typed_instances,
        binary_columns_list = binary_columns_list
    )
    mlflow.log_param(key = "binary_columns_list", value=binary_columns_list)
    columns_order = preprocessing.fit_columns_order(data = instances_without_missing_values)
    with open((target_directory / "columns_order.pkl").as_posix(), "wb") as file:
        pickle.dump(columns_order, file)
    mlflow.log_artifact(
        local_path=(target_directory / "columns_order.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    instances_with_correct_columns_order = preprocessing.transform_columns_order(
        data = instances_without_missing_values,
        columns_order = columns_order
    )
    numerical_data, categorical_data = preprocessing.split_numeric_and_categorical_data(
        data=instances_with_correct_columns_order
    )

    encoder = preprocessing.fit_categorical_encoder(
        data = categorical_data, 
        unknown_value = unknown_value
    )
    with open((target_directory / "encoder.pkl").as_posix(), "wb") as file:
        pickle.dump(encoder, file)
    mlflow.log_artifact(
        local_path=(target_directory / "encoder.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    encoded_categorical_data = preprocessing.transform_categorical_encoder(
        data = categorical_data,
        encoder = encoder 
    )

    ml_features = preprocessing.concatenate_numerical_and_categorical_data(
        numerical_data = numerical_data,
        categorical_data = encoded_categorical_data
    )
    LOGGER.info("Saving the final table...")
    ml_features.to_parquet((target_directory / "ml_features.parquet").as_posix())


    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Training the model...")
    x_train, x_test, y_train, y_test = ml_training.apply_train_test_split(
        x = ml_features, 
        y= ml_labels,
        test_size = test_size,
        shuffle = shuffle, 
        random_state = random_state
    )
    mlflow.log_param(key="test_size", value=test_size)
    mlflow.log_param(key="shuffle", value=shuffle)
    mlflow.log_param(key="random_state", value=random_state)

    xgb_model = ml_training.train_xgb_model(
        x_train = x_train,
        x_test = x_test,
        y_train = y_train,
        y_test = y_test,
        hyperparameters = hyperparameters,
        training_params = training_params,
    )
    mlflow.log_params(hyperparameters)
    mlflow.log_params(training_params)
    with open((target_directory / "xgb_model.pkl").as_posix(), "wb") as file:
        pickle.dump(xgb_model, file)
    mlflow.log_artifact(
        local_path=(target_directory / "xgb_model.pkl").as_posix(), 
        artifact_path="model_artifacts"
    )

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Explaining the model...")
    target_directory = (Path().cwd().parent / "data/04_model_outputs/")
    target_directory.mkdir(parents=True, exist_ok=True)
    shap_values_train = explanation.create_shap_values(
        data = x_train,
        model = xgb_model
    )
    importance_variables_plot = explanation.plot_importance_variables(
        model=xgb_model,
        data=x_train
    )
    importance_variables_plot.savefig(
        (target_directory / "importance_variables_xgb.png").as_posix(),  
        bbox_inches="tight"
    )
    mlflow.log_artifact(
        local_path=(target_directory / "importance_variables_xgb.png").as_posix(), 
        artifact_path="model_explanation"
    )

    dependence_plots = explanation.plot_dependence_plots(
        data=x_train,
        shap_values = shap_values_train,
        encoder=encoder
    )
    for key, value in dependence_plots.items():
        filepath = (target_directory / "dependence_plots")
        filepath.mkdir(parents=True, exist_ok=True)
        value.savefig(
            (filepath / key).as_posix(),  
            bbox_inches="tight"
        )
        mlflow.log_artifact(
            local_path=(filepath / key).as_posix(), 
            artifact_path="model_explanation"
        )

    LOGGER.info("-------------------------------------------------")
    LOGGER.info("Evaluating the model...")
    y_probs_test = prediction.predict_probs(data=x_test, model=xgb_model)
    classification_reports = evaluation.create_classification_reports(
        y_true=y_test, y_probs= y_probs_test, thresholds = [0.25,0.3,0.4,0.5,0.6]
    )
    with open((target_directory / "classification_reports.json").as_posix(), "w") as file :
        json.dump(classification_reports, file)
    mlflow.log_artifact(
        local_path=(target_directory / "classification_reports.json").as_posix(), 
        artifact_path="model_evaluation"
    )
# Out:
# 2025-07-14 10:47:05,427 : WARNING : Retrying (Retry(total=6, connect=6, read=7, redirect=7, status=7)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000249EC22A710>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée')': /api/2.0/mlflow/experiments/get-by-name?experiment_name=technical_test
# 2025-07-14 10:47:13,966 : WARNING : Retrying (Retry(total=5, connect=5, read=7, redirect=7, status=7)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000249EE846910>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée')': /api/2.0/mlflow/experiments/get-by-name?experiment_name=technical_test
# 2025-07-14 10:47:26,984 : WARNING : Retrying (Retry(total=4, connect=4, read=7, redirect=7, status=7)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000249EE8478D0>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée')': /api/2.0/mlflow/experiments/get-by-name?experiment_name=technical_test
# 2025-07-14 10:47:29,307 : INFO : -------------------------------------------------
# 2025-07-14 10:47:29,307 : INFO : Pre processing : Labels...
# 2025-07-14 10:47:29,318 : INFO : labels.tp_fraud.value_counts().to_dict() = {0.0: 753, 1.0: 247}
# 2025-07-14 10:47:29,318 : INFO : Saving the final table...
# 2025-07-14 10:47:29,323 : INFO : -------------------------------------------------
# 2025-07-14 10:47:29,323 : INFO : Pre processing : Instances...
# 2025-07-14 10:47:29,481 : INFO : numerical_data.columns = Index(['insured_zip', 'umbrella_limit', 'vehicle_claim', 'per_accident_limit',
#        'policy_annual_premium', 'number_of_vehicles_involved',
#        'nb_years_between_incident_and_bind_date', 'incident_hour_of_the_day',
#        'policy_deductable', 'months_as_customer', 'per_person_limit', 'age',
#        'property_claim', 'capital-gains', 'witnesses', 'auto_year',
#        'capital-loss', 'injury_claim', 'bodily_injuries'],
#       dtype='object')
# 2025-07-14 10:47:29,481 : INFO : categorical_data.columns = Index(['property_damage', 'insured_occupation', 'collision_type',
#        'incident_state', 'incident_severity', 'auto_make', 'policy_state',
#        'incident_type', 'police_report_available', 'incident_city',
#        'insured_hobbies', 'authorities_contacted', 'insured_education_level'],
#       dtype='object')
# 2025-07-14 10:47:29,530 : INFO : Saving the final table...
# 2025-07-14 10:47:29,542 : INFO : -------------------------------------------------
# 2025-07-14 10:47:29,543 : INFO : Training the model...
# [0]	validation_0-auc:0.56605	validation_0-logloss:0.62229
# [1]	validation_0-auc:0.72426	validation_0-logloss:0.61936
# [2]	validation_0-auc:0.87245	validation_0-logloss:0.61500
# [3]	validation_0-auc:0.85564	validation_0-logloss:0.61511
# [4]	validation_0-auc:0.86331	validation_0-logloss:0.61286
# [5]	validation_0-auc:0.89055	validation_0-logloss:0.60857
# [6]	validation_0-auc:0.91178	validation_0-logloss:0.60337
# [7]	validation_0-auc:0.90966	validation_0-logloss:0.60125
# [8]	validation_0-auc:0.91579	validation_0-logloss:0.59728
# [9]	validation_0-auc:0.91909	validation_0-logloss:0.59314
# [10]	validation_0-auc:0.91909	validation_0-logloss:0.59130
# [11]	validation_0-auc:0.91473	validation_0-logloss:0.59143
# [12]	validation_0-auc:0.91225	validation_0-logloss:0.59110
# [13]	validation_0-auc:0.91650	validation_0-logloss:0.58719
# [14]	validation_0-auc:0.91544	validation_0-logloss:0.58710
# [15]	validation_0-auc:0.91485	validation_0-logloss:0.58619
# [16]	validation_0-auc:0.91273	validation_0-logloss:0.58602
# [17]	validation_0-auc:0.91414	validation_0-logloss:0.58372
# [18]	validation_0-auc:0.91261	validation_0-logloss:0.58392
# [19]	validation_0-auc:0.91461	validation_0-logloss:0.58019
# [20]	validation_0-auc:0.91343	validation_0-logloss:0.57688
# [21]	validation_0-auc:0.91249	validation_0-logloss:0.57490
# [22]	validation_0-auc:0.91296	validation_0-logloss:0.57160
# [23]	validation_0-auc:0.91190	validation_0-logloss:0.57027
# [24]	validation_0-auc:0.91237	validation_0-logloss:0.57004
# [25]	validation_0-auc:0.91214	validation_0-logloss:0.56664
# [26]	validation_0-auc:0.91355	validation_0-logloss:0.56468
# [27]	validation_0-auc:0.91284	validation_0-logloss:0.56240
# [28]	validation_0-auc:0.91532	validation_0-logloss:0.55925
# [29]	validation_0-auc:0.91556	validation_0-logloss:0.55898
# [30]	validation_0-auc:0.91438	validation_0-logloss:0.55727
# [31]	validation_0-auc:0.91567	validation_0-logloss:0.55734
# [32]	validation_0-auc:0.91273	validation_0-logloss:0.55740
# [33]	validation_0-auc:0.91273	validation_0-logloss:0.55446
# [34]	validation_0-auc:0.91485	validation_0-logloss:0.55128
# [35]	validation_0-auc:0.91379	validation_0-logloss:0.55070
# [36]	validation_0-auc:0.91473	validation_0-logloss:0.55065
# [37]	validation_0-auc:0.91556	validation_0-logloss:0.54722
# [38]	validation_0-auc:0.91780	validation_0-logloss:0.54663
# [39]	validation_0-auc:0.91662	validation_0-logloss:0.54506
# [40]	validation_0-auc:0.91685	validation_0-logloss:0.54236
# [41]	validation_0-auc:0.91674	validation_0-logloss:0.53931
# [42]	validation_0-auc:0.91803	validation_0-logloss:0.53624
# [43]	validation_0-auc:0.91815	validation_0-logloss:0.53460
# [44]	validation_0-auc:0.91803	validation_0-logloss:0.53315
# [45]	validation_0-auc:0.91791	validation_0-logloss:0.53081
# [46]	validation_0-auc:0.91933	validation_0-logloss:0.52763
# [47]	validation_0-auc:0.91921	validation_0-logloss:0.52481
# [48]	validation_0-auc:0.91874	validation_0-logloss:0.52240
# [49]	validation_0-auc:0.91933	validation_0-logloss:0.51977
# [50]	validation_0-auc:0.91874	validation_0-logloss:0.51735
# [51]	validation_0-auc:0.91721	validation_0-logloss:0.51509
# [52]	validation_0-auc:0.91685	validation_0-logloss:0.51269
# [53]	validation_0-auc:0.91721	validation_0-logloss:0.51000
# [54]	validation_0-auc:0.91815	validation_0-logloss:0.50804
# [55]	validation_0-auc:0.91850	validation_0-logloss:0.50575
# [56]	validation_0-auc:0.91768	validation_0-logloss:0.50358
# [57]	validation_0-auc:0.91674	validation_0-logloss:0.50156
# [58]	validation_0-auc:0.91591	validation_0-logloss:0.50074
# [59]	validation_0-auc:0.91709	validation_0-logloss:0.49834
# [60]	validation_0-auc:0.91768	validation_0-logloss:0.49580
# [61]	validation_0-auc:0.91850	validation_0-logloss:0.49482
# [62]	validation_0-auc:0.91886	validation_0-logloss:0.49239
# [63]	validation_0-auc:0.91791	validation_0-logloss:0.49103
# [64]	validation_0-auc:0.91709	validation_0-logloss:0.48921
# [65]	validation_0-auc:0.91756	validation_0-logloss:0.48912
# [66]	validation_0-auc:0.91685	validation_0-logloss:0.48750
# [67]	validation_0-auc:0.91567	validation_0-logloss:0.48746
# [68]	validation_0-auc:0.91650	validation_0-logloss:0.48551
# [69]	validation_0-auc:0.91685	validation_0-logloss:0.48462
# [70]	validation_0-auc:0.91556	validation_0-logloss:0.48410
# [71]	validation_0-auc:0.91520	validation_0-logloss:0.48197
# [72]	validation_0-auc:0.91473	validation_0-logloss:0.48029
# [73]	validation_0-auc:0.91520	validation_0-logloss:0.47792
# [74]	validation_0-auc:0.91508	validation_0-logloss:0.47627
# [75]	validation_0-auc:0.91461	validation_0-logloss:0.47447
# [76]	validation_0-auc:0.91449	validation_0-logloss:0.47260
# [77]	validation_0-auc:0.91449	validation_0-logloss:0.47100
# [78]	validation_0-auc:0.91449	validation_0-logloss:0.47052
# [79]	validation_0-auc:0.91355	validation_0-logloss:0.46896
# [80]	validation_0-auc:0.91379	validation_0-logloss:0.46747
# [81]	validation_0-auc:0.91402	validation_0-logloss:0.46613
# [82]	validation_0-auc:0.91438	validation_0-logloss:0.46444
# [83]	validation_0-auc:0.91426	validation_0-logloss:0.46278
# [84]	validation_0-auc:0.91390	validation_0-logloss:0.46101
# [85]	validation_0-auc:0.91438	validation_0-logloss:0.46097
# [86]	validation_0-auc:0.91390	validation_0-logloss:0.46032
# [87]	validation_0-auc:0.91355	validation_0-logloss:0.45863
# [88]	validation_0-auc:0.91379	validation_0-logloss:0.45841
# [89]	validation_0-auc:0.91414	validation_0-logloss:0.45840
# [90]	validation_0-auc:0.91414	validation_0-logloss:0.45677
# [91]	validation_0-auc:0.91438	validation_0-logloss:0.45530
# [92]	validation_0-auc:0.91520	validation_0-logloss:0.45436
# [93]	validation_0-auc:0.91520	validation_0-logloss:0.45445
# [94]	validation_0-auc:0.91520	validation_0-logloss:0.45375
# [95]	validation_0-auc:0.91485	validation_0-logloss:0.45303
# [96]	validation_0-auc:0.91638	validation_0-logloss:0.45298
# [97]	validation_0-auc:0.91615	validation_0-logloss:0.45170
# [98]	validation_0-auc:0.91626	validation_0-logloss:0.45050
# [99]	validation_0-auc:0.91733	validation_0-logloss:0.44881
# [100]	validation_0-auc:0.91756	validation_0-logloss:0.44897
# [101]	validation_0-auc:0.91721	validation_0-logloss:0.44881
# [102]	validation_0-auc:0.91756	validation_0-logloss:0.44702
# [103]	validation_0-auc:0.91709	validation_0-logloss:0.44566
# [104]	validation_0-auc:0.91756	validation_0-logloss:0.44390
# [105]	validation_0-auc:0.91803	validation_0-logloss:0.44215
# [106]	validation_0-auc:0.91815	validation_0-logloss:0.44072
# [107]	validation_0-auc:0.91874	validation_0-logloss:0.43931
# [108]	validation_0-auc:0.91850	validation_0-logloss:0.43814
# [109]	validation_0-auc:0.91850	validation_0-logloss:0.43637
# [110]	validation_0-auc:0.91980	validation_0-logloss:0.43623
# [111]	validation_0-auc:0.91921	validation_0-logloss:0.43508
# [112]	validation_0-auc:0.91839	validation_0-logloss:0.43406
# [113]	validation_0-auc:0.91898	validation_0-logloss:0.43275
# [114]	validation_0-auc:0.91874	validation_0-logloss:0.43123
# [115]	validation_0-auc:0.91874	validation_0-logloss:0.43120
# [116]	validation_0-auc:0.91839	validation_0-logloss:0.43005
# [117]	validation_0-auc:0.91780	validation_0-logloss:0.42923
# [118]	validation_0-auc:0.91721	validation_0-logloss:0.42881
# [119]	validation_0-auc:0.91803	validation_0-logloss:0.42798
# [120]	validation_0-auc:0.91839	validation_0-logloss:0.42670
# [121]	validation_0-auc:0.91815	validation_0-logloss:0.42561
# [122]	validation_0-auc:0.91697	validation_0-logloss:0.42506
# [123]	validation_0-auc:0.91674	validation_0-logloss:0.42409
# [124]	validation_0-auc:0.91579	validation_0-logloss:0.42325
# [125]	validation_0-auc:0.91662	validation_0-logloss:0.42179
# [126]	validation_0-auc:0.91721	validation_0-logloss:0.42061
# [127]	validation_0-auc:0.91697	validation_0-logloss:0.41935
# [128]	validation_0-auc:0.91685	validation_0-logloss:0.41839
# [129]	validation_0-auc:0.91733	validation_0-logloss:0.41719
# [130]	validation_0-auc:0.91685	validation_0-logloss:0.41651
# [131]	validation_0-auc:0.91803	validation_0-logloss:0.41566
# [132]	validation_0-auc:0.91756	validation_0-logloss:0.41472
# [133]	validation_0-auc:0.91756	validation_0-logloss:0.41384
# [134]	validation_0-auc:0.91803	validation_0-logloss:0.41263
# [135]	validation_0-auc:0.91791	validation_0-logloss:0.41160
# [136]	validation_0-auc:0.91768	validation_0-logloss:0.41098
# [137]	validation_0-auc:0.91839	validation_0-logloss:0.41082
# [138]	validation_0-auc:0.91709	validation_0-logloss:0.41045
# [139]	validation_0-auc:0.91803	validation_0-logloss:0.40990
# [140]	validation_0-auc:0.91803	validation_0-logloss:0.40894
# [141]	validation_0-auc:0.91803	validation_0-logloss:0.40807
# [142]	validation_0-auc:0.91803	validation_0-logloss:0.40712
# [143]	validation_0-auc:0.91803	validation_0-logloss:0.40643
# [144]	validation_0-auc:0.91815	validation_0-logloss:0.40620
# [145]	validation_0-auc:0.91921	validation_0-logloss:0.40550
# [146]	validation_0-auc:0.91957	validation_0-logloss:0.40523
# [147]	validation_0-auc:0.91945	validation_0-logloss:0.40433
# [148]	validation_0-auc:0.91921	validation_0-logloss:0.40446
# [149]	validation_0-auc:0.91909	validation_0-logloss:0.40358
# [150]	validation_0-auc:0.91886	validation_0-logloss:0.40266
# [151]	validation_0-auc:0.91945	validation_0-logloss:0.40208
# [152]	validation_0-auc:0.91898	validation_0-logloss:0.40107
# [153]	validation_0-auc:0.91898	validation_0-logloss:0.40019
# [154]	validation_0-auc:0.91909	validation_0-logloss:0.39996
# [155]	validation_0-auc:0.91898	validation_0-logloss:0.39933
# [156]	validation_0-auc:0.91909	validation_0-logloss:0.39850
# [157]	validation_0-auc:0.91839	validation_0-logloss:0.39829
# [158]	validation_0-auc:0.91850	validation_0-logloss:0.39783
# [159]	validation_0-auc:0.91886	validation_0-logloss:0.39669
# [160]	validation_0-auc:0.91850	validation_0-logloss:0.39580
# [161]	validation_0-auc:0.91945	validation_0-logloss:0.39583
# [162]	validation_0-auc:0.91933	validation_0-logloss:0.39494
# [163]	validation_0-auc:0.91921	validation_0-logloss:0.39424
# [164]	validation_0-auc:0.91921	validation_0-logloss:0.39320
# [165]	validation_0-auc:0.91968	validation_0-logloss:0.39269
# [166]	validation_0-auc:0.92016	validation_0-logloss:0.39196
# [167]	validation_0-auc:0.92004	validation_0-logloss:0.39132
# [168]	validation_0-auc:0.92004	validation_0-logloss:0.39052
# [169]	validation_0-auc:0.92004	validation_0-logloss:0.38974
# [170]	validation_0-auc:0.91957	validation_0-logloss:0.38955
# [171]	validation_0-auc:0.91886	validation_0-logloss:0.38872
# [172]	validation_0-auc:0.91921	validation_0-logloss:0.38888
# [173]	validation_0-auc:0.91933	validation_0-logloss:0.38804
# [174]	validation_0-auc:0.91957	validation_0-logloss:0.38704
# [175]	validation_0-auc:0.91968	validation_0-logloss:0.38629
# [176]	validation_0-auc:0.91933	validation_0-logloss:0.38623
# [177]	validation_0-auc:0.91992	validation_0-logloss:0.38628
# [178]	validation_0-auc:0.91980	validation_0-logloss:0.38532
# [179]	validation_0-auc:0.91980	validation_0-logloss:0.38457
# [180]	validation_0-auc:0.92027	validation_0-logloss:0.38448
# [181]	validation_0-auc:0.92039	validation_0-logloss:0.38396
# [182]	validation_0-auc:0.91980	validation_0-logloss:0.38374
# [183]	validation_0-auc:0.91968	validation_0-logloss:0.38305
# [184]	validation_0-auc:0.91968	validation_0-logloss:0.38297
# [185]	validation_0-auc:0.92016	validation_0-logloss:0.38281
# [186]	validation_0-auc:0.92051	validation_0-logloss:0.38244
# [187]	validation_0-auc:0.92051	validation_0-logloss:0.38189
# [188]	validation_0-auc:0.92086	validation_0-logloss:0.38124
# [189]	validation_0-auc:0.92051	validation_0-logloss:0.38064
# [190]	validation_0-auc:0.92098	validation_0-logloss:0.38078
# [191]	validation_0-auc:0.92016	validation_0-logloss:0.38013
# [192]	validation_0-auc:0.92051	validation_0-logloss:0.37952
# [193]	validation_0-auc:0.92016	validation_0-logloss:0.37912
# [194]	validation_0-auc:0.92016	validation_0-logloss:0.37885
# [195]	validation_0-auc:0.92016	validation_0-logloss:0.37860
# [196]	validation_0-auc:0.92051	validation_0-logloss:0.37811
# [197]	validation_0-auc:0.92075	validation_0-logloss:0.37778
# [198]	validation_0-auc:0.92075	validation_0-logloss:0.37733
# [199]	validation_0-auc:0.92063	validation_0-logloss:0.37720
# [200]	validation_0-auc:0.92051	validation_0-logloss:0.37665
# [201]	validation_0-auc:0.92051	validation_0-logloss:0.37594
# [202]	validation_0-auc:0.91992	validation_0-logloss:0.37568
# [203]	validation_0-auc:0.92039	validation_0-logloss:0.37552
# [204]	validation_0-auc:0.92051	validation_0-logloss:0.37481
# [205]	validation_0-auc:0.92063	validation_0-logloss:0.37522
# [206]	validation_0-auc:0.91980	validation_0-logloss:0.37508
# [207]	validation_0-auc:0.91957	validation_0-logloss:0.37492
# [208]	validation_0-auc:0.91933	validation_0-logloss:0.37445
# [209]	validation_0-auc:0.92004	validation_0-logloss:0.37374
# [210]	validation_0-auc:0.92016	validation_0-logloss:0.37313
# [211]	validation_0-auc:0.92039	validation_0-logloss:0.37259
# [212]	validation_0-auc:0.92051	validation_0-logloss:0.37204
# [213]	validation_0-auc:0.92016	validation_0-logloss:0.37163
# [214]	validation_0-auc:0.92027	validation_0-logloss:0.37158
# [215]	validation_0-auc:0.92004	validation_0-logloss:0.37127
# [216]	validation_0-auc:0.92027	validation_0-logloss:0.37071
# [217]	validation_0-auc:0.91980	validation_0-logloss:0.37063
# [218]	validation_0-auc:0.91992	validation_0-logloss:0.37073
# [219]	validation_0-auc:0.91933	validation_0-logloss:0.37084
# [220]	validation_0-auc:0.91945	validation_0-logloss:0.37035
# [221]	validation_0-auc:0.91980	validation_0-logloss:0.37042
# [222]	validation_0-auc:0.91980	validation_0-logloss:0.37016
# [223]	validation_0-auc:0.92016	validation_0-logloss:0.36955
# [224]	validation_0-auc:0.91980	validation_0-logloss:0.36923
# [225]	validation_0-auc:0.92016	validation_0-logloss:0.36860
# [226]	validation_0-auc:0.91980	validation_0-logloss:0.36804
# [227]	validation_0-auc:0.91957	validation_0-logloss:0.36788
# [228]	validation_0-auc:0.92016	validation_0-logloss:0.36741
# [229]	validation_0-auc:0.91980	validation_0-logloss:0.36670
# [230]	validation_0-auc:0.91980	validation_0-logloss:0.36630
# [231]	validation_0-auc:0.92027	validation_0-logloss:0.36619
# [232]	validation_0-auc:0.92051	validation_0-logloss:0.36581
# [233]	validation_0-auc:0.92063	validation_0-logloss:0.36565
# [234]	validation_0-auc:0.92075	validation_0-logloss:0.36538
# [235]	validation_0-auc:0.92110	validation_0-logloss:0.36538
# [236]	validation_0-auc:0.92122	validation_0-logloss:0.36544
# [237]	validation_0-auc:0.92075	validation_0-logloss:0.36557
# [238]	validation_0-auc:0.92110	validation_0-logloss:0.36514
# [239]	validation_0-auc:0.92157	validation_0-logloss:0.36475
# [240]	validation_0-auc:0.92169	validation_0-logloss:0.36475
# [241]	validation_0-auc:0.92204	validation_0-logloss:0.36462
# [242]	validation_0-auc:0.92228	validation_0-logloss:0.36393
# [243]	validation_0-auc:0.92216	validation_0-logloss:0.36374
# [244]	validation_0-auc:0.92228	validation_0-logloss:0.36315
# [245]	validation_0-auc:0.92216	validation_0-logloss:0.36326
# [246]	validation_0-auc:0.92157	validation_0-logloss:0.36271
# [247]	validation_0-auc:0.92169	validation_0-logloss:0.36233
# [248]	validation_0-auc:0.92192	validation_0-logloss:0.36171
# [249]	validation_0-auc:0.92216	validation_0-logloss:0.36187
# [250]	validation_0-auc:0.92228	validation_0-logloss:0.36146
# [251]	validation_0-auc:0.92251	validation_0-logloss:0.36127
# [252]	validation_0-auc:0.92251	validation_0-logloss:0.36113
# [253]	validation_0-auc:0.92240	validation_0-logloss:0.36067
# [254]	validation_0-auc:0.92263	validation_0-logloss:0.36062
# [255]	validation_0-auc:0.92310	validation_0-logloss:0.36014
# [256]	validation_0-auc:0.92393	validation_0-logloss:0.35999
# [257]	validation_0-auc:0.92369	validation_0-logloss:0.35949
# [258]	validation_0-auc:0.92393	validation_0-logloss:0.35943
# [259]	validation_0-auc:0.92381	validation_0-logloss:0.35908
# [260]	validation_0-auc:0.92369	validation_0-logloss:0.35882
# [261]	validation_0-auc:0.92346	validation_0-logloss:0.35852
# [262]	validation_0-auc:0.92381	validation_0-logloss:0.35818
# [263]	validation_0-auc:0.92369	validation_0-logloss:0.35830
# [264]	validation_0-auc:0.92275	validation_0-logloss:0.35826
# [265]	validation_0-auc:0.92310	validation_0-logloss:0.35793
# [266]	validation_0-auc:0.92299	validation_0-logloss:0.35811
# [267]	validation_0-auc:0.92287	validation_0-logloss:0.35814
# [268]	validation_0-auc:0.92322	validation_0-logloss:0.35814
# [269]	validation_0-auc:0.92322	validation_0-logloss:0.35819
# [270]	validation_0-auc:0.92275	validation_0-logloss:0.35800
# [271]	validation_0-auc:0.92275	validation_0-logloss:0.35826
# [272]	validation_0-auc:0.92263	validation_0-logloss:0.35792
# [273]	validation_0-auc:0.92310	validation_0-logloss:0.35771
# [274]	validation_0-auc:0.92334	validation_0-logloss:0.35729
# [275]	validation_0-auc:0.92369	validation_0-logloss:0.35698
# [276]	validation_0-auc:0.92369	validation_0-logloss:0.35636
# [277]	validation_0-auc:0.92405	validation_0-logloss:0.35608
# [278]	validation_0-auc:0.92440	validation_0-logloss:0.35595
# [279]	validation_0-auc:0.92393	validation_0-logloss:0.35560
# [280]	validation_0-auc:0.92440	validation_0-logloss:0.35520
# [281]	validation_0-auc:0.92452	validation_0-logloss:0.35508
# [282]	validation_0-auc:0.92405	validation_0-logloss:0.35531
# [283]	validation_0-auc:0.92428	validation_0-logloss:0.35509
# [284]	validation_0-auc:0.92440	validation_0-logloss:0.35503
# [285]	validation_0-auc:0.92393	validation_0-logloss:0.35515
# [286]	validation_0-auc:0.92405	validation_0-logloss:0.35452
# [287]	validation_0-auc:0.92428	validation_0-logloss:0.35437
# [288]	validation_0-auc:0.92358	validation_0-logloss:0.35420
# [289]	validation_0-auc:0.92334	validation_0-logloss:0.35422
# [290]	validation_0-auc:0.92334	validation_0-logloss:0.35384
# [291]	validation_0-auc:0.92369	validation_0-logloss:0.35367
# [292]	validation_0-auc:0.92381	validation_0-logloss:0.35365
# [293]	validation_0-auc:0.92334	validation_0-logloss:0.35355
# [294]	validation_0-auc:0.92369	validation_0-logloss:0.35326
# [295]	validation_0-auc:0.92310	validation_0-logloss:0.35332
# [296]	validation_0-auc:0.92263	validation_0-logloss:0.35329
# [297]	validation_0-auc:0.92240	validation_0-logloss:0.35310
# [298]	validation_0-auc:0.92334	validation_0-logloss:0.35263
# [299]	validation_0-auc:0.92381	validation_0-logloss:0.35214
# [300]	validation_0-auc:0.92322	validation_0-logloss:0.35211
# [301]	validation_0-auc:0.92322	validation_0-logloss:0.35177
# [302]	validation_0-auc:0.92322	validation_0-logloss:0.35168
# [303]	validation_0-auc:0.92275	validation_0-logloss:0.35156
# [304]	validation_0-auc:0.92358	validation_0-logloss:0.35125
# [305]	validation_0-auc:0.92334	validation_0-logloss:0.35104
# [306]	validation_0-auc:0.92322	validation_0-logloss:0.35096
# [307]	validation_0-auc:0.92334	validation_0-logloss:0.35089
# [308]	validation_0-auc:0.92287	validation_0-logloss:0.35064
# [309]	validation_0-auc:0.92275	validation_0-logloss:0.35053
# [310]	validation_0-auc:0.92240	validation_0-logloss:0.35061
# [311]	validation_0-auc:0.92299	validation_0-logloss:0.34994
# [312]	validation_0-auc:0.92369	validation_0-logloss:0.34946
# [313]	validation_0-auc:0.92381	validation_0-logloss:0.34921
# [314]	validation_0-auc:0.92310	validation_0-logloss:0.34894
# [315]	validation_0-auc:0.92310	validation_0-logloss:0.34898
# [316]	validation_0-auc:0.92299	validation_0-logloss:0.34886
# [317]	validation_0-auc:0.92310	validation_0-logloss:0.34917
# [318]	validation_0-auc:0.92287	validation_0-logloss:0.34863
# [319]	validation_0-auc:0.92310	validation_0-logloss:0.34843
# [320]	validation_0-auc:0.92346	validation_0-logloss:0.34808
# [321]	validation_0-auc:0.92310	validation_0-logloss:0.34781
# [322]	validation_0-auc:0.92369	validation_0-logloss:0.34761
# [323]	validation_0-auc:0.92405	validation_0-logloss:0.34730
# [324]	validation_0-auc:0.92440	validation_0-logloss:0.34695
# [325]	validation_0-auc:0.92405	validation_0-logloss:0.34661
# [326]	validation_0-auc:0.92405	validation_0-logloss:0.34634
# [327]	validation_0-auc:0.92417	validation_0-logloss:0.34650
# [328]	validation_0-auc:0.92417	validation_0-logloss:0.34630
# [329]	validation_0-auc:0.92452	validation_0-logloss:0.34626
# [330]	validation_0-auc:0.92358	validation_0-logloss:0.34635
# [331]	validation_0-auc:0.92381	validation_0-logloss:0.34625
# [332]	validation_0-auc:0.92405	validation_0-logloss:0.34592
# [333]	validation_0-auc:0.92381	validation_0-logloss:0.34579
# [334]	validation_0-auc:0.92322	validation_0-logloss:0.34582
# [335]	validation_0-auc:0.92334	validation_0-logloss:0.34550
# [336]	validation_0-auc:0.92381	validation_0-logloss:0.34521
# [337]	validation_0-auc:0.92369	validation_0-logloss:0.34533
# [338]	validation_0-auc:0.92381	validation_0-logloss:0.34519
# [339]	validation_0-auc:0.92346	validation_0-logloss:0.34530
# [340]	validation_0-auc:0.92346	validation_0-logloss:0.34509
# [341]	validation_0-auc:0.92369	validation_0-logloss:0.34508
# [342]	validation_0-auc:0.92358	validation_0-logloss:0.34494
# [343]	validation_0-auc:0.92381	validation_0-logloss:0.34487
# [344]	validation_0-auc:0.92393	validation_0-logloss:0.34495
# [345]	validation_0-auc:0.92405	validation_0-logloss:0.34449
# [346]	validation_0-auc:0.92417	validation_0-logloss:0.34446
# [347]	validation_0-auc:0.92428	validation_0-logloss:0.34459
# [348]	validation_0-auc:0.92417	validation_0-logloss:0.34440
# [349]	validation_0-auc:0.92511	validation_0-logloss:0.34450
# [350]	validation_0-auc:0.92464	validation_0-logloss:0.34424
# [351]	validation_0-auc:0.92452	validation_0-logloss:0.34400
# [352]	validation_0-auc:0.92476	validation_0-logloss:0.34388
# [353]	validation_0-auc:0.92487	validation_0-logloss:0.34349
# [354]	validation_0-auc:0.92476	validation_0-logloss:0.34338
# [355]	validation_0-auc:0.92487	validation_0-logloss:0.34304
# [356]	validation_0-auc:0.92476	validation_0-logloss:0.34288
# [357]	validation_0-auc:0.92381	validation_0-logloss:0.34269
# [358]	validation_0-auc:0.92428	validation_0-logloss:0.34275
# [359]	validation_0-auc:0.92417	validation_0-logloss:0.34273
# [360]	validation_0-auc:0.92487	validation_0-logloss:0.34234
# [361]	validation_0-auc:0.92487	validation_0-logloss:0.34203
# [362]	validation_0-auc:0.92487	validation_0-logloss:0.34210
# [363]	validation_0-auc:0.92464	validation_0-logloss:0.34226
# [364]	validation_0-auc:0.92487	validation_0-logloss:0.34216
# [365]	validation_0-auc:0.92440	validation_0-logloss:0.34210
# [366]	validation_0-auc:0.92405	validation_0-logloss:0.34228
# [367]	validation_0-auc:0.92452	validation_0-logloss:0.34229
# [368]	validation_0-auc:0.92417	validation_0-logloss:0.34217
# [369]	validation_0-auc:0.92405	validation_0-logloss:0.34219
# [370]	validation_0-auc:0.92369	validation_0-logloss:0.34227
# [371]	validation_0-auc:0.92381	validation_0-logloss:0.34193
# [372]	validation_0-auc:0.92417	validation_0-logloss:0.34197
# [373]	validation_0-auc:0.92369	validation_0-logloss:0.34204
# [374]	validation_0-auc:0.92381	validation_0-logloss:0.34195
# [375]	validation_0-auc:0.92393	validation_0-logloss:0.34175
# [376]	validation_0-auc:0.92428	validation_0-logloss:0.34191
# [377]	validation_0-auc:0.92440	validation_0-logloss:0.34172
# [378]	validation_0-auc:0.92440	validation_0-logloss:0.34170
# [379]	validation_0-auc:0.92487	validation_0-logloss:0.34158
# [380]	validation_0-auc:0.92476	validation_0-logloss:0.34153
# [381]	validation_0-auc:0.92464	validation_0-logloss:0.34126
# [382]	validation_0-auc:0.92487	validation_0-logloss:0.34146
# [383]	validation_0-auc:0.92558	validation_0-logloss:0.34156
# [384]	validation_0-auc:0.92546	validation_0-logloss:0.34122
# [385]	validation_0-auc:0.92558	validation_0-logloss:0.34114
# [386]	validation_0-auc:0.92511	validation_0-logloss:0.34113
# [387]	validation_0-auc:0.92546	validation_0-logloss:0.34125
# [388]	validation_0-auc:0.92534	validation_0-logloss:0.34117
# [389]	validation_0-auc:0.92558	validation_0-logloss:0.34104
# [390]	validation_0-auc:0.92593	validation_0-logloss:0.34129
# [391]	validation_0-auc:0.92582	validation_0-logloss:0.34113
# [392]	validation_0-auc:0.92593	validation_0-logloss:0.34103
# [393]	validation_0-auc:0.92582	validation_0-logloss:0.34083
# [394]	validation_0-auc:0.92570	validation_0-logloss:0.34076
# [395]	validation_0-auc:0.92605	validation_0-logloss:0.34073
# [396]	validation_0-auc:0.92558	validation_0-logloss:0.34045
# [397]	validation_0-auc:0.92546	validation_0-logloss:0.34046
# [398]	validation_0-auc:0.92570	validation_0-logloss:0.34015
# [399]	validation_0-auc:0.92570	validation_0-logloss:0.34021
# [400]	validation_0-auc:0.92570	validation_0-logloss:0.33984
# [401]	validation_0-auc:0.92558	validation_0-logloss:0.33946
# [402]	validation_0-auc:0.92570	validation_0-logloss:0.33935
# [403]	validation_0-auc:0.92534	validation_0-logloss:0.33945
# [404]	validation_0-auc:0.92487	validation_0-logloss:0.33927
# [405]	validation_0-auc:0.92534	validation_0-logloss:0.33914
# [406]	validation_0-auc:0.92558	validation_0-logloss:0.33887
# [407]	validation_0-auc:0.92593	validation_0-logloss:0.33892
# [408]	validation_0-auc:0.92523	validation_0-logloss:0.33911
# [409]	validation_0-auc:0.92546	validation_0-logloss:0.33905
# [410]	validation_0-auc:0.92546	validation_0-logloss:0.33906
# [411]	validation_0-auc:0.92558	validation_0-logloss:0.33922
# [412]	validation_0-auc:0.92582	validation_0-logloss:0.33943
# [413]	validation_0-auc:0.92593	validation_0-logloss:0.33951
# [414]	validation_0-auc:0.92558	validation_0-logloss:0.33936
# [415]	validation_0-auc:0.92546	validation_0-logloss:0.33944
# [416]	validation_0-auc:0.92511	validation_0-logloss:0.33946
# [417]	validation_0-auc:0.92534	validation_0-logloss:0.33929
# [418]	validation_0-auc:0.92523	validation_0-logloss:0.33932
# [419]	validation_0-auc:0.92534	validation_0-logloss:0.33928
# [420]	validation_0-auc:0.92523	validation_0-logloss:0.33914
# 2025-07-14 10:47:49,292 : INFO : -------------------------------------------------
# 2025-07-14 10:47:49,293 : INFO : Explaining the model...
# 2025-07-14 10:47:56,224 : INFO : -------------------------------------------------
# 2025-07-14 10:47:56,232 : INFO : Evaluating the model...
# 🏃 View run model_training at: http://localhost:5000/#/experiments/222123412902236260/runs/5d2bcbbb6268423495a132cffde844ee
# 🧪 View experiment at: http://localhost:5000/#/experiments/222123412902236260

# %% [markdown]
# # **Conclusions & more**
#
# - the idea was to predict the probability of fraud and then choose a threshold to determine wether a predicted individual is a fraud or not
# - the problem was a binary classification with imbalanced classes so it is better to do so instead of predicting the class directly (most of the time the threshold is fixed at 50% so with an imbalanced classification the true positives will likely stay at 0)
# - what metrics did I choose during model training ? : minimizing the log loss
#     - for an imbalanced classification, it is better to predict probabilities and then choose a threshold (every probs >= threshold will be considered as a fraud)
#     - the log loss is a "distance" between the labels and the predicted probabilities, so minimizing it will help calibrate the model
# - what metrics did I choose to evaluate the model ? :
#     - precision
#     - recall
#     - the confusion matrix
# - these are the prefered metrics in this case because :
#     - for fraud detection what matters the most is the nb of fraud detected and the amount of cases the model predicts as a high risk of fraud
#     - for an imbalanced classification problem looking at the accuracy is not advised (if i only have 5% of 1 in my labels, by predicting everyone to 0 i will have a 95% accuracy)
# - what are the results ? :
#
#     - when grouping high cardinality categorical variables :
# ```json
# {
#     "classification_report_threshold_25%": {
#         "precision": 0.6774193548387096,
#         "recal": 0.6885245901639344,
#         "true_positives": 42.0,
#         "false_positives": 20.0,
#         "true_negatives": 119.0,
#         "false_negatives": 19.0
#     },
#     "classification_report_threshold_30%": {
#         "precision": 0.7272727272727273,
#         "recal": 0.6557377049180327,
#         "true_positives": 40.0,
#         "false_positives": 15.0,
#         "true_negatives": 124.0,
#         "false_negatives": 21.0
#     },
#     "classification_report_threshold_40%": {
#         "precision": 0.7391304347826086,
#         "recal": 0.5573770491803278,
#         "true_positives": 34.0,
#         "false_positives": 12.0,
#         "true_negatives": 127.0,
#         "false_negatives": 27.0
#     },
#     "classification_report_threshold_50%": {
#         "precision": 0.8484848484848485,
#         "recal": 0.45901639344262296,
#         "true_positives": 28.0,
#         "false_positives": 5.0,
#         "true_negatives": 134.0,
#         "false_negatives": 33.0
#     },
#     "classification_report_threshold_60%": {
#         "precision": 0.8666666666666667,
#         "recal": 0.21311475409836064,
#         "true_positives": 13.0,
#         "false_positives": 2.0,
#         "true_negatives": 137.0,
#         "false_negatives": 48.0
#     }
# }
# ```
# - the goal is to find a balance between precision and recall, we want to detect enough frauds but without making too much controls, fraud investigations are usually quite costly for insurance companies.
#
#     - when not grouping high cardinality categorical variables :
#
# ```json
# {
#   "classification_report_threshold_25%": {
#     "precision": 0.7671232876712328,
#     "recal": 0.9180327868852459,
#     "true_positives": 56,
#     "false_positives": 17,
#     "true_negatives": 122,
#     "false_negatives": 5
#   },
#   "classification_report_threshold_30%": {
#     "precision": 0.7681159420289855,
#     "recal": 0.8688524590163934,
#     "true_positives": 53,
#     "false_positives": 16,
#     "true_negatives": 123,
#     "false_negatives": 8
#   },
#   "classification_report_threshold_40%": {
#     "precision": 0.7627118644067796,
#     "recal": 0.7377049180327869,
#     "true_positives": 45,
#     "false_positives": 14,
#     "true_negatives": 125,
#     "false_negatives": 16
#   },
#   "classification_report_threshold_50%": {
#     "precision": 0.7857142857142857,
#     "recal": 0.5409836065573771,
#     "true_positives": 33,
#     "false_positives": 9,
#     "true_negatives": 130,
#     "false_negatives": 28
#   },
#   "classification_report_threshold_60%": {
#     "precision": 0.8333333333333334,
#     "recal": 0.32786885245901637,
#     "true_positives": 20,
#     "false_positives": 4,
#     "true_negatives": 135,
#     "false_negatives": 41
#   }
# }
# ```
# - we observe a significant change in performance if we group the high cardinality variables or not -> we will choose not to
#     - the XGBoost can handle high cardinality variables when using OrdinalEncoder because it splits each node using a "question-based" threshold
#     - `feature_1 >= threshold ?`
# - the goal is to find a balance between precision and recall, we want to detect enough frauds but without making too much controls, fraud investigations are usually quite costly for insurance companies.
# - the great compromise in our case could be choosing a threshold around 25~30%
